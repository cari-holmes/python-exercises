# %%
import pandas as pd

#1. Use pandas to create a Series from the following data: ["kiwi", "mango", "strawberry", "pineapple", "gala apple", "honeycrisp apple", "tomato", "watermelon", "honeydew", "kiwi", "kiwi", "kiwi", "mango", "blueberry", "blackberry", "gooseberry", "papaya"]
pd.Series(["kiwi", "mango", "strawberry", "pineapple", "gala apple", "honeycrisp apple", "tomato", "watermelon", "honeydew", "kiwi", "kiwi", "kiwi", "mango", "blueberry", "blackberry", "gooseberry", "papaya"])
# Out:
# 0                 kiwi
# 1                mango
# 2           strawberry
# 3            pineapple
# 4           gala apple
# 5     honeycrisp apple
# 6               tomato
# 7           watermelon
# 8             honeydew
# 9                 kiwi
# 10                kiwi
# 11                kiwi
# 12               mango
# 13           blueberry
# 14          blackberry
# 15          gooseberry
# 16              papaya
# dtype: object

# %%
#A. Name the variable that holds the series fruits.
fruits = pd.Series(["kiwi", "mango", "strawberry", "pineapple", "gala apple", "honeycrisp apple", "tomato", "watermelon", "honeydew", "kiwi", "kiwi", "kiwi", "mango", "blueberry", "blackberry", "gooseberry", "papaya"])
fruits
# Out:
# 0                 kiwi
# 1                mango
# 2           strawberry
# 3            pineapple
# 4           gala apple
# 5     honeycrisp apple
# 6               tomato
# 7           watermelon
# 8             honeydew
# 9                 kiwi
# 10                kiwi
# 11                kiwi
# 12               mango
# 13           blueberry
# 14          blackberry
# 15          gooseberry
# 16              papaya
# dtype: object

# %%
#B. Run .describe() on the series to see what describe returns for a series of strings.
fruits.describe()
# Out:
# count       17
# unique      13
# top       kiwi
# freq         4
# dtype: object

# %%
#C. Run the code necessary to produce only the unique fruit names.
fruits.unique()
# Out:
# array(['kiwi', 'mango', 'strawberry', 'pineapple', 'gala apple',
#        'honeycrisp apple', 'tomato', 'watermelon', 'honeydew',
#        'blueberry', 'blackberry', 'gooseberry', 'papaya'], dtype=object)

# %%
#D. Determine how many times each value occurs in the series.
fruits.value_counts()
# Out:
# kiwi                4
# mango               2
# gooseberry          1
# blueberry           1
# gala apple          1
# strawberry          1
# honeydew            1
# blackberry          1
# tomato              1
# honeycrisp apple    1
# pineapple           1
# watermelon          1
# papaya              1
# dtype: int64

# %%
#E. Determine the most frequently occurring fruit name from the series.
#most_frequent = fruits.value_counts().max() #gives us back the highest value
fruit = fruits.value_counts().idxmax()
fruit
#fruits.mode()
# Out:
# 'kiwi'

# %%
#F. Determine the least frequently occurring fruit name from the series.
least_frequent = fruits.value_counts().min() #gives us back lowest value
#fruits.value_counts().idxmin()
fruits.value_counts()[fruits.value_counts() == least_frequent] # comparing the value count to the lowest value count
# Out:
# gooseberry          1
# blueberry           1
# gala apple          1
# strawberry          1
# honeydew            1
# blackberry          1
# tomato              1
# honeycrisp apple    1
# pineapple           1
# watermelon          1
# papaya              1
# dtype: int64

# %%
#G. Write the code to get the longest string from the fruits series.
#.idmax()
fruit_name = fruits.unique()
fruit_name = pd.Series(fruit_name)
length = fruit_name.str.len().max()
index = fruit_name.str.len().idxmax()
longest_string = fruit_name[index]
longest_string
# Out:
# 'honeycrisp apple'

# %%
#H. Find the fruit(s) with 5 or more letters in the name.
fruits[fruits.apply(lambda x: len(x) >= 5)]
# Out:
# 1                mango
# 2           strawberry
# 3            pineapple
# 4           gala apple
# 5     honeycrisp apple
# 6               tomato
# 7           watermelon
# 8             honeydew
# 12               mango
# 13           blueberry
# 14          blackberry
# 15          gooseberry
# 16              papaya
# dtype: object

# %%
#I. Capitalize all the fruit strings in the series.
fruits.str.capitalize()
# Out:
# 0                 Kiwi
# 1                Mango
# 2           Strawberry
# 3            Pineapple
# 4           Gala apple
# 5     Honeycrisp apple
# 6               Tomato
# 7           Watermelon
# 8             Honeydew
# 9                 Kiwi
# 10                Kiwi
# 11                Kiwi
# 12               Mango
# 13           Blueberry
# 14          Blackberry
# 15          Gooseberry
# 16              Papaya
# dtype: object

# %%
#J. Count the letter "a" in all the fruits (use string vectorization)
def count_a(word):
    return word.count('a')
fruits.apply(count_a)   

counts = fruits.str.count('a')
fruit_name
list(zip(fruit_name, counts))
# Out:
# [('kiwi', 0),
#  ('mango', 1),
#  ('strawberry', 1),
#  ('pineapple', 1),
#  ('gala apple', 3),
#  ('honeycrisp apple', 1),
#  ('tomato', 1),
#  ('watermelon', 1),
#  ('honeydew', 0),
#  ('blueberry', 0),
#  ('blackberry', 0),
#  ('gooseberry', 0),
#  ('papaya', 1)]

# %%
#K. Output the number of vowels in each and every fruit.
def count_vowels(word):
    count = 0
    for letter in word:
        if letter in "aeiou":
            count += 1
    return count

fruits.apply(count_vowels)
#make a list(zip) to show names with numbers
# Out:
# 0     2
# 1     2
# 2     2
# 3     4
# 4     4
# 5     5
# 6     3
# 7     4
# 8     3
# 9     2
# 10    2
# 11    2
# 12    2
# 13    3
# 14    2
# 15    4
# 16    3
# dtype: int64

# %%
#L.Use the .apply method and a lambda function to find the fruit(s) containing two or more "o" letters in the name.
fruits.apply(lambda x: x.count('o') >= 2)
fruits[fruits.apply(lambda x: x.count('o') >= 2)]
# Out:
# 6         tomato
# 15    gooseberry
# dtype: object

# %%
#M. Write the code to get only the fruits containing "berry" in the name
fruits[fruits.str.contains('berry')]
# Out:
# 2     strawberry
# 13     blueberry
# 14    blackberry
# 15    gooseberry
# dtype: object

# %%
#N. Write the code to get only the fruits containing "apple" in the name
fruits[fruits.str.contains('apple')]
# Out:
# 3           pineapple
# 4          gala apple
# 5    honeycrisp apple
# dtype: object

# %%
#O. Which fruit has the highest amount of vowels?
#fruits[fruits.apply(count_vowels).max()], fruits.apply(count_vowels).max() ---> just happened to be on index 5, not reliable solution
fruits[fruits.apply(count_vowels).idxmax()], fruits.apply(count_vowels).idxmax()
# Out:
# ('honeycrisp apple', 5)

# %%
#2. Use pandas to create a Series from the following data: ['$796,459.41', '$278.60', '$482,571.67', '$4,503,915.98', '$2,121,418.3', '$1,260,813.3', '$87,231.01', '$1,509,175.45', '$4,138,548.00', '$2,848,913.80', '$594,715.39', '$4,789,988.17', '$4,513,644.5', '$3,191,059.97', '$1,758,712.24', '$4,338,283.54', '$4,738,303.38', '$2,791,759.67', '$769,681.94', '$452,650.23']
amount = pd.Series(['$796,459.41', '$278.60', '$482,571.67', '$4,503,915.98', '$2,121,418.3', '$1,260,813.3', '$87,231.01', '$1,509,175.45', '$4,138,548.00', '$2,848,913.80', '$594,715.39', '$4,789,988.17', '$4,513,644.5', '$3,191,059.97', '$1,758,712.24', '$4,338,283.54', '$4,738,303.38', '$2,791,759.67', '$769,681.94', '$452,650.23'])
amount
# Out:
# 0       $796,459.41
# 1           $278.60
# 2       $482,571.67
# 3     $4,503,915.98
# 4      $2,121,418.3
# 5      $1,260,813.3
# 6        $87,231.01
# 7     $1,509,175.45
# 8     $4,138,548.00
# 9     $2,848,913.80
# 10      $594,715.39
# 11    $4,789,988.17
# 12     $4,513,644.5
# 13    $3,191,059.97
# 14    $1,758,712.24
# 15    $4,338,283.54
# 16    $4,738,303.38
# 17    $2,791,759.67
# 18      $769,681.94
# 19      $452,650.23
# dtype: object

# %%
#A. What is the data type of the series?
amount.dtype
# Out:
# dtype('O')

# %%
#B. Use series operations to convert the series to a numeric data type.
replace_char = amount.str.replace('$', "").str.replace(',', '')
replace_char
new_amount = replace_char.astype(float)
new_amount.dtype
new_amount
# Out:
# 0      796459.41
# 1         278.60
# 2      482571.67
# 3     4503915.98
# 4     2121418.30
# 5     1260813.30
# 6       87231.01
# 7     1509175.45
# 8     4138548.00
# 9     2848913.80
# 10     594715.39
# 11    4789988.17
# 12    4513644.50
# 13    3191059.97
# 14    1758712.24
# 15    4338283.54
# 16    4738303.38
# 17    2791759.67
# 18     769681.94
# 19     452650.23
# dtype: float64

# %%
#C. What is the maximum value? The minimum?
print("max amount:", new_amount.max())
print("min amount:", new_amount.min())
# Out:
# max amount: 4789988.17
# min amount: 278.6

# %%
#D. Bin the data into 4 equally sized intervals and show how many values fall into each bin.
cut = pd.cut(new_amount, 4)
print(cut)

print("Counts by bin")
print(cut.value_counts())
# Out:
# 0        (-4511.11, 1197705.993]
# 1        (-4511.11, 1197705.993]
# 2        (-4511.11, 1197705.993]
# 3      (3592560.778, 4789988.17]
# 4     (1197705.993, 2395133.385]
# 5     (1197705.993, 2395133.385]
# 6        (-4511.11, 1197705.993]
# 7     (1197705.993, 2395133.385]
# 8      (3592560.778, 4789988.17]
# 9     (2395133.385, 3592560.778]
# 10       (-4511.11, 1197705.993]
# 11     (3592560.778, 4789988.17]
# 12     (3592560.778, 4789988.17]
# 13    (2395133.385, 3592560.778]
# 14    (1197705.993, 2395133.385]
# 15     (3592560.778, 4789988.17]
# 16     (3592560.778, 4789988.17]
# 17    (2395133.385, 3592560.778]
# 18       (-4511.11, 1197705.993]
# 19       (-4511.11, 1197705.993]
# dtype: category
# Categories (4, interval[float64]): [(-4511.11, 1197705.993] < (1197705.993, 2395133.385] < (2395133.385, 3592560.778] < (3592560.778, 4789988.17]]
# Counts by bin
# (-4511.11, 1197705.993]       7
# (3592560.778, 4789988.17]     6
# (1197705.993, 2395133.385]    4
# (2395133.385, 3592560.778]    3
# dtype: int64

# %%
##E. Plot a histogram of the data. Be sure to include a title and axis labels.
import matplotlib as plt
new_amount.plot.hist()

# %%
#3. Use pandas to create a Series from the following exam scores: [60, 86, 75, 62, 93, 71, 60, 83, 95, 78, 65, 72, 69, 81, 96, 80, 85, 92, 82, 78]
scores = pd.Series([60, 86, 75, 62, 93, 71, 60, 83, 95, 78, 65, 72, 69, 81, 96, 80, 85, 92, 82, 78])
scores
# Out:
# 0     60
# 1     86
# 2     75
# 3     62
# 4     93
# 5     71
# 6     60
# 7     83
# 8     95
# 9     78
# 10    65
# 11    72
# 12    69
# 13    81
# 14    96
# 15    80
# 16    85
# 17    92
# 18    82
# 19    78
# dtype: int64

# %%
#A. What is the minimum exam score? The max, mean, median?
print("max scores:", scores.min())
print("min scores:", scores.max())
print("mean scores:", scores.mean())
print("median scores:", scores.median())
# Out:
# max scores: 60
# min scores: 96
# mean scores: 78.15
# median scores: 79.0

# %%
#B. Plot a histogram of the scores.
import matplotlib as plt
scores.plot.hist()

# %%
#C. Convert each of the numbers above into a letter grade. For example, 86 should be a 'B' and 95 should be an 'A'.
def grades(x):
    if x > 90:
        return 'A'
    elif x > 80:
        return 'B'
    elif x > 70:
        return 'C'
    elif x > 60:
        return 'D'
    else:
        return 'F'
    
letter_grades = scores.apply(grades)
letter_grades

# letter_grade = pd.cut(scores, bins = [0, 60, 70, 80, 90, 100], labels = ['F', 'D', 'C', 'B', 'A'])
# letter_grade
# Out:
# 0     F
# 1     B
# 2     C
# 3     D
# 4     A
# 5     C
# 6     F
# 7     B
# 8     A
# 9     C
# 10    D
# 11    C
# 12    D
# 13    B
# 14    A
# 15    C
# 16    B
# 17    A
# 18    B
# 19    C
# dtype: object

# %%
##D. Write the code necessary to implement a curve. I.e. that grade closest to 100 should be converted to a 100, and that many points should be given to every other score as well.
max_score = scores.max()
max_score
curve = 100 - max_score
curve
# Out:
# 4

# %%
#4. Use pandas to create a Series from the following string: 'hnvidduckkqxwymbimkccexbkmqygkxoyndmcxnwqarhyffsjpsrabtjzsypmzadfavyrnndndvswreauxovncxtwzpwejilzjrmmbbgbyxvjtewqthafnbkqplarokkyydtubbmnexoypulzwfhqvckdpqtpoppzqrmcvhhpwgjwupgzhiofohawytlsiyecuproguy'
long_string = pd.Series(list('hnvidduckkqxwymbimkccexbkmqygkxoyndmcxnwqarhyffsjpsrabtjzsypmzadfavyrnndndvswreauxovncxtwzpwejilzjrmmbbgbyxvjtewqthafnbkqplarokkyydtubbmnexoypulzwfhqvckdpqtpoppzqrmcvhhpwgjwupgzhiofohawytlsiyecuproguy'))
long_string
# Out:
# 0      h
# 1      n
# 2      v
# 3      i
# 4      d
# 5      d
# 6      u
# 7      c
# 8      k
# 9      k
# 10     q
# 11     x
# 12     w
# 13     y
# 14     m
# 15     b
# 16     i
# 17     m
# 18     k
# 19     c
# 20     c
# 21     e
# 22     x
# 23     b
# 24     k
# 25     m
# 26     q
# 27     y
# 28     g
# 29     k
#       ..
# 170    g
# 171    j
# 172    w
# 173    u
# 174    p
# 175    g
# 176    z
# 177    h
# 178    i
# 179    o
# 180    f
# 181    o
# 182    h
# 183    a
# 184    w
# 185    y
# 186    t
# 187    l
# 188    s
# 189    i
# 190    y
# 191    e
# 192    c
# 193    u
# 194    p
# 195    r
# 196    o
# 197    g
# 198    u
# 199    y
# Length: 200, dtype: object

# %%
##A. What is the most frequently occuring letter? Least frequently occuring?
frequencies = long_string.value_counts()
most = frequencies.max()
least = frequencies.min()
print(long_string[frequencies.max()], ":" , most)
print(long_string[frequencies.min()], ":" , least)
# Out:
# y : 13
# d : 4

# %%
#B. How many vowels are in the list?
def count_vowels(word):
    count = 0
    for letter in word:
        if letter in "aeiou":
            count += 1
    return count
vowels = long_string.apply(count_vowels)
vowels.sum()
# Out:
# 34

# %%
#C. How many consonants are in the list?
def count_consonants(word):
    count = 0
    for letter in word:
        if letter not in "aeiou":
            count += 1
    return count
consonants = long_string.apply(count_consonants)
consonants.sum()
# Out:
# 166

# %%
##D. Create a series that has all of the same letters, but uppercased
long_string.str.upper()
# Out:
# 0      H
# 1      N
# 2      V
# 3      I
# 4      D
# 5      D
# 6      U
# 7      C
# 8      K
# 9      K
# 10     Q
# 11     X
# 12     W
# 13     Y
# 14     M
# 15     B
# 16     I
# 17     M
# 18     K
# 19     C
# 20     C
# 21     E
# 22     X
# 23     B
# 24     K
# 25     M
# 26     Q
# 27     Y
# 28     G
# 29     K
#       ..
# 170    G
# 171    J
# 172    W
# 173    U
# 174    P
# 175    G
# 176    Z
# 177    H
# 178    I
# 179    O
# 180    F
# 181    O
# 182    H
# 183    A
# 184    W
# 185    Y
# 186    T
# 187    L
# 188    S
# 189    I
# 190    Y
# 191    E
# 192    C
# 193    U
# 194    P
# 195    R
# 196    O
# 197    G
# 198    U
# 199    Y
# Length: 200, dtype: object

# %%
#E. Create a bar plot of the frequencies of the 6 most frequently occuring letters.
import matplotlib as plt
graph = long_string.value_counts().head(6)
graph.plot.bar(title="Six Most Frequent")

# %%
from pydataset import data
# Out:
# initiated datasets repo at: /Users/cariholmes/.pydataset/

# %%
#1. Copy the code from the lesson to create a dataframe full of student grades. 
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
#A. Create a column named passing_english that indicates whether each student has a passing grade in reading.
df['passing_english'] = df.english > 70
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
#B. Sort the english grades by the passing_english column. How are duplicates handled?
df.sort_values(by='english')
# duplicates are handled by referring to the name column and then going alphabetically from there.
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
##C. Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)
df.sort_values(by=['english','name'],ascending=True)
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
#D. Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step. 
df.sort_values(by=['passing_english','english'], ascending=False)
# Out:
#        name  math  english  reading  passing_english
# 10    Isaac    92       99       93             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 0     Sally    62       85       80             True
# 9   Richard    69       80       94             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 2     Suzie    94       74       95             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False

# %%
##E. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.
#df['overall_grade'] = [df['math', 'english', 'reading']].mean()
df
# Out:
#        name  math  english  reading  overall_grade
# 0     Sally    62       85       80     173.666667
# 1      Jane    88       79       67     189.333333
# 2     Suzie    94       74       95     199.666667
# 3     Billy    98       96       88     223.333333
# 4       Ada    77       92       98     201.666667
# 5      John    79       76       93     186.000000
# 6    Thomas    82       64       81     173.000000
# 7     Marie    93       63       90     186.000000
# 8    Albert    92       62       87     183.000000
# 9   Richard    69       80       94     180.333333
# 10    Isaac    92       99       93     222.000000
# 11     Alan    92       62       72     178.000000

# %%
#2. Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:
from pydataset import data
mpg = data('mpg')
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 13          audi              a4 quattro    2.8  1999    6  manual(m5)   4
# 14          audi              a4 quattro    3.1  2008    6    auto(s6)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8    auto(s6)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 25     chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 26     chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 27     chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 28     chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 30     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 31     chevrolet         k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 33     chevrolet                  malibu    2.4  1999    4    auto(l4)   f
# 34     chevrolet                  malibu    2.4  2008    4    auto(l4)   f
# 35     chevrolet                  malibu    3.1  1999    6    auto(l4)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 37     chevrolet                  malibu    3.6  2008    6    auto(s6)   f
# 38         dodge             caravan 2wd    2.4  1999    4    auto(l3)   f
# 39         dodge             caravan 2wd    3.0  1999    6    auto(l4)   f
# 40         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 41         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 42         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 43         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 44         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 45         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 46         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 47         dodge             caravan 2wd    3.8  2008    6    auto(l6)   f
# 48         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 49         dodge       dakota pickup 4wd    3.7  2008    6  manual(m6)   4
# 50         dodge       dakota pickup 4wd    3.7  2008    6    auto(l4)   4
# 51         dodge       dakota pickup 4wd    3.9  1999    6    auto(l4)   4
# 52         dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 53         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 54         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 55         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 56         dodge       dakota pickup 4wd    5.2  1999    8  manual(m5)   4
# 57         dodge       dakota pickup 4wd    5.2  1999    8    auto(l4)   4
# 58         dodge             durango 4wd    3.9  1999    6    auto(l4)   4
# 59         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 60         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 61         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 62         dodge             durango 4wd    5.2  1999    8    auto(l4)   4
# 63         dodge             durango 4wd    5.7  2008    8    auto(l5)   4
# 64         dodge             durango 4wd    5.9  1999    8    auto(l4)   4
# 65         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 69         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 70         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 71         dodge     ram 1500 pickup 4wd    5.2  1999    8    auto(l4)   4
# 72         dodge     ram 1500 pickup 4wd    5.2  1999    8  manual(m5)   4
# 73         dodge     ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4
# 74         dodge     ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4
# 75          ford          expedition 2wd    4.6  1999    8    auto(l4)   r
# 76          ford          expedition 2wd    5.4  1999    8    auto(l4)   r
# 77          ford          expedition 2wd    5.4  2008    8    auto(l6)   r
# 78          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 79          ford            explorer 4wd    4.0  1999    6  manual(m5)   4
# 80          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 81          ford            explorer 4wd    4.0  2008    6    auto(l5)   4
# 82          ford            explorer 4wd    4.6  2008    8    auto(l6)   4
# 83          ford            explorer 4wd    5.0  1999    8    auto(l4)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6    auto(l4)   4
# 85          ford         f150 pickup 4wd    4.2  1999    6  manual(m5)   4
# ..           ...                     ...    ...   ...  ...         ...  ..
# 150       nissan                  maxima    3.5  2008    6    auto(av)   f
# 151       nissan          pathfinder 4wd    3.3  1999    6    auto(l4)   4
# 152       nissan          pathfinder 4wd    3.3  1999    6  manual(m5)   4
# 153       nissan          pathfinder 4wd    4.0  2008    6    auto(l5)   4
# 154       nissan          pathfinder 4wd    5.6  2008    8    auto(s5)   4
# 155      pontiac              grand prix    3.1  1999    6    auto(l4)   f
# 156      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 157      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 158      pontiac              grand prix    3.8  2008    6    auto(l4)   f
# 159      pontiac              grand prix    5.3  2008    8    auto(s4)   f
# 160       subaru            forester awd    2.5  1999    4  manual(m5)   4
# 161       subaru            forester awd    2.5  1999    4    auto(l4)   4
# 162       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 163       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 164       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 165       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 166       subaru             impreza awd    2.2  1999    4    auto(l4)   4
# 167       subaru             impreza awd    2.2  1999    4  manual(m5)   4
# 168       subaru             impreza awd    2.5  1999    4  manual(m5)   4
# 169       subaru             impreza awd    2.5  1999    4    auto(l4)   4
# 170       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 171       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 172       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 173       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 174       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
# 175       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4
# 177       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 178       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 179       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 180       toyota                   camry    2.2  1999    4  manual(m5)   f
# 181       toyota                   camry    2.2  1999    4    auto(l4)   f
# 182       toyota                   camry    2.4  2008    4  manual(m5)   f
# 183       toyota                   camry    2.4  2008    4    auto(l5)   f
# 184       toyota                   camry    3.0  1999    6    auto(l4)   f
# 185       toyota                   camry    3.0  1999    6  manual(m5)   f
# 186       toyota                   camry    3.5  2008    6    auto(s6)   f
# 187       toyota            camry solara    2.2  1999    4    auto(l4)   f
# 188       toyota            camry solara    2.2  1999    4  manual(m5)   f
# 189       toyota            camry solara    2.4  2008    4  manual(m5)   f
# 190       toyota            camry solara    2.4  2008    4    auto(s5)   f
# 191       toyota            camry solara    3.0  1999    6    auto(l4)   f
# 192       toyota            camry solara    3.0  1999    6  manual(m5)   f
# 193       toyota            camry solara    3.3  2008    6    auto(s5)   f
# 194       toyota                 corolla    1.8  1999    4    auto(l3)   f
# 195       toyota                 corolla    1.8  1999    4    auto(l4)   f
# 196       toyota                 corolla    1.8  1999    4  manual(m5)   f
# 197       toyota                 corolla    1.8  2008    4  manual(m5)   f
# 198       toyota                 corolla    1.8  2008    4    auto(l4)   f
# 199       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 200       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4
# 201       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4
# 202       toyota       toyota tacoma 4wd    2.7  1999    4    auto(l4)   4
# 203       toyota       toyota tacoma 4wd    2.7  2008    4  manual(m5)   4
# 204       toyota       toyota tacoma 4wd    3.4  1999    6  manual(m5)   4
# 205       toyota       toyota tacoma 4wd    3.4  1999    6    auto(l4)   4
# 206       toyota       toyota tacoma 4wd    4.0  2008    6  manual(m6)   4
# 207       toyota       toyota tacoma 4wd    4.0  2008    6    auto(l5)   4
# 208   volkswagen                     gti    2.0  1999    4  manual(m5)   f
# 209   volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 210   volkswagen                     gti    2.0  2008    4  manual(m6)   f
# 211   volkswagen                     gti    2.0  2008    4    auto(s6)   f
# 212   volkswagen                     gti    2.8  1999    6  manual(m5)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 214   volkswagen                   jetta    2.0  1999    4  manual(m5)   f
# 215   volkswagen                   jetta    2.0  1999    4    auto(l4)   f
# 216   volkswagen                   jetta    2.0  2008    4    auto(s6)   f
# 217   volkswagen                   jetta    2.0  2008    4  manual(m6)   f
# 218   volkswagen                   jetta    2.5  2008    5    auto(s6)   f
# 219   volkswagen                   jetta    2.5  2008    5  manual(m5)   f
# 220   volkswagen                   jetta    2.8  1999    6    auto(l4)   f
# 221   volkswagen                   jetta    2.8  1999    6  manual(m5)   f
# 222   volkswagen              new beetle    1.9  1999    4  manual(m5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 224   volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 225   volkswagen              new beetle    2.0  1999    4    auto(l4)   f
# 226   volkswagen              new beetle    2.5  2008    5  manual(m5)   f
# 227   volkswagen              new beetle    2.5  2008    5    auto(s6)   f
# 228   volkswagen                  passat    1.8  1999    4  manual(m5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 230   volkswagen                  passat    2.0  2008    4    auto(s6)   f
# 231   volkswagen                  passat    2.0  2008    4  manual(m6)   f
# 232   volkswagen                  passat    2.8  1999    6    auto(l5)   f
# 233   volkswagen                  passat    2.8  1999    6  manual(m5)   f
# 234   volkswagen                  passat    3.6  2008    6    auto(s6)   f
#
#      cty  hwy fl       class
# 1     18   29  p     compact
# 2     21   29  p     compact
# 3     20   31  p     compact
# 4     21   30  p     compact
# 5     16   26  p     compact
# 6     18   26  p     compact
# 7     18   27  p     compact
# 8     18   26  p     compact
# 9     16   25  p     compact
# 10    20   28  p     compact
# 11    19   27  p     compact
# 12    15   25  p     compact
# 13    17   25  p     compact
# 14    17   25  p     compact
# 15    15   25  p     compact
# 16    15   24  p     midsize
# 17    17   25  p     midsize
# 18    16   23  p     midsize
# 19    14   20  r         suv
# 20    11   15  e         suv
# 21    14   20  r         suv
# 22    13   17  r         suv
# 23    12   17  r         suv
# 24    16   26  p     2seater
# 25    15   23  p     2seater
# 26    16   26  p     2seater
# 27    15   25  p     2seater
# 28    15   24  p     2seater
# 29    14   19  r         suv
# 30    11   14  e         suv
# 31    11   15  r         suv
# 32    14   17  d         suv
# 33    19   27  r     midsize
# 34    22   30  r     midsize
# 35    18   26  r     midsize
# 36    18   29  r     midsize
# 37    17   26  r     midsize
# 38    18   24  r     minivan
# 39    17   24  r     minivan
# 40    16   22  r     minivan
# 41    16   22  r     minivan
# 42    17   24  r     minivan
# 43    17   24  r     minivan
# 44    11   17  e     minivan
# 45    15   22  r     minivan
# 46    15   21  r     minivan
# 47    16   23  r     minivan
# 48    16   23  r     minivan
# 49    15   19  r      pickup
# 50    14   18  r      pickup
# 51    13   17  r      pickup
# 52    14   17  r      pickup
# 53    14   19  r      pickup
# 54    14   19  r      pickup
# 55     9   12  e      pickup
# 56    11   17  r      pickup
# 57    11   15  r      pickup
# 58    13   17  r         suv
# 59    13   17  r         suv
# 60     9   12  e         suv
# 61    13   17  r         suv
# 62    11   16  r         suv
# 63    13   18  r         suv
# 64    11   15  r         suv
# 65    12   16  r      pickup
# 66     9   12  e      pickup
# 67    13   17  r      pickup
# 68    13   17  r      pickup
# 69    12   16  r      pickup
# 70     9   12  e      pickup
# 71    11   15  r      pickup
# 72    11   16  r      pickup
# 73    13   17  r      pickup
# 74    11   15  r      pickup
# 75    11   17  r         suv
# 76    11   17  r         suv
# 77    12   18  r         suv
# 78    14   17  r         suv
# 79    15   19  r         suv
# 80    14   17  r         suv
# 81    13   19  r         suv
# 82    13   19  r         suv
# 83    13   17  r         suv
# 84    14   17  r      pickup
# 85    14   17  r      pickup
# ..   ...  ... ..         ...
# 150   19   25  p     midsize
# 151   14   17  r         suv
# 152   15   17  r         suv
# 153   14   20  p         suv
# 154   12   18  p         suv
# 155   18   26  r     midsize
# 156   16   26  p     midsize
# 157   17   27  r     midsize
# 158   18   28  r     midsize
# 159   16   25  p     midsize
# 160   18   25  r         suv
# 161   18   24  r         suv
# 162   20   27  r         suv
# 163   19   25  p         suv
# 164   20   26  r         suv
# 165   18   23  p         suv
# 166   21   26  r  subcompact
# 167   19   26  r  subcompact
# 168   19   26  r  subcompact
# 169   19   26  r  subcompact
# 170   20   25  p     compact
# 171   20   27  r     compact
# 172   19   25  p     compact
# 173   20   27  r     compact
# 174   15   20  r         suv
# 175   16   20  r         suv
# 176   15   19  r         suv
# 177   15   17  r         suv
# 178   16   20  r         suv
# 179   14   17  r         suv
# 180   21   29  r     midsize
# 181   21   27  r     midsize
# 182   21   31  r     midsize
# 183   21   31  r     midsize
# 184   18   26  r     midsize
# 185   18   26  r     midsize
# 186   19   28  r     midsize
# 187   21   27  r     compact
# 188   21   29  r     compact
# 189   21   31  r     compact
# 190   22   31  r     compact
# 191   18   26  r     compact
# 192   18   26  r     compact
# 193   18   27  r     compact
# 194   24   30  r     compact
# 195   24   33  r     compact
# 196   26   35  r     compact
# 197   28   37  r     compact
# 198   26   35  r     compact
# 199   11   15  r         suv
# 200   13   18  r         suv
# 201   15   20  r      pickup
# 202   16   20  r      pickup
# 203   17   22  r      pickup
# 204   15   17  r      pickup
# 205   15   19  r      pickup
# 206   15   18  r      pickup
# 207   16   20  r      pickup
# 208   21   29  r     compact
# 209   19   26  r     compact
# 210   21   29  p     compact
# 211   22   29  p     compact
# 212   17   24  r     compact
# 213   33   44  d     compact
# 214   21   29  r     compact
# 215   19   26  r     compact
# 216   22   29  p     compact
# 217   21   29  p     compact
# 218   21   29  r     compact
# 219   21   29  r     compact
# 220   16   23  r     compact
# 221   17   24  r     compact
# 222   35   44  d  subcompact
# 223   29   41  d  subcompact
# 224   21   29  r  subcompact
# 225   19   26  r  subcompact
# 226   20   28  r  subcompact
# 227   20   29  r  subcompact
# 228   21   29  p     midsize
# 229   18   29  p     midsize
# 230   19   28  p     midsize
# 231   21   29  p     midsize
# 232   16   26  p     midsize
# 233   18   26  p     midsize
# 234   17   26  p     midsize
#
# [234 rows x 11 columns]

# %%
#A. How many rows and columns are there?
mpg.shape
# Out:
# (234, 13)

# %%
#B. What are the data types of each column?
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
#C. Summarize the dataframe with .info and .describe
mpg.info(), mpg.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB
# (None,             displ         year         cyl         cty         hwy
#  count  234.000000   234.000000  234.000000  234.000000  234.000000
#  mean     3.471795  2003.500000    5.888889   16.858974   23.440171
#  std      1.291959     4.509646    1.611534    4.255946    5.954643
#  min      1.600000  1999.000000    4.000000    9.000000   12.000000
#  25%      2.400000  1999.000000    4.000000   14.000000   18.000000
#  50%      3.300000  2003.500000    6.000000   17.000000   24.000000
#  75%      4.600000  2008.000000    8.000000   19.000000   27.000000
#  max      7.000000  2008.000000    8.000000   35.000000   44.000000)

# %%
#D. Rename the cty column to city.
mpg.rename(columns={'cty' : 'city'})
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 13          audi              a4 quattro    2.8  1999    6  manual(m5)   4
# 14          audi              a4 quattro    3.1  2008    6    auto(s6)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8    auto(s6)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 25     chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 26     chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 27     chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 28     chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 30     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 31     chevrolet         k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 33     chevrolet                  malibu    2.4  1999    4    auto(l4)   f
# 34     chevrolet                  malibu    2.4  2008    4    auto(l4)   f
# 35     chevrolet                  malibu    3.1  1999    6    auto(l4)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 37     chevrolet                  malibu    3.6  2008    6    auto(s6)   f
# 38         dodge             caravan 2wd    2.4  1999    4    auto(l3)   f
# 39         dodge             caravan 2wd    3.0  1999    6    auto(l4)   f
# 40         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 41         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 42         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 43         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 44         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 45         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 46         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 47         dodge             caravan 2wd    3.8  2008    6    auto(l6)   f
# 48         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 49         dodge       dakota pickup 4wd    3.7  2008    6  manual(m6)   4
# 50         dodge       dakota pickup 4wd    3.7  2008    6    auto(l4)   4
# 51         dodge       dakota pickup 4wd    3.9  1999    6    auto(l4)   4
# 52         dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 53         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 54         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 55         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 56         dodge       dakota pickup 4wd    5.2  1999    8  manual(m5)   4
# 57         dodge       dakota pickup 4wd    5.2  1999    8    auto(l4)   4
# 58         dodge             durango 4wd    3.9  1999    6    auto(l4)   4
# 59         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 60         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 61         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 62         dodge             durango 4wd    5.2  1999    8    auto(l4)   4
# 63         dodge             durango 4wd    5.7  2008    8    auto(l5)   4
# 64         dodge             durango 4wd    5.9  1999    8    auto(l4)   4
# 65         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 69         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 70         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 71         dodge     ram 1500 pickup 4wd    5.2  1999    8    auto(l4)   4
# 72         dodge     ram 1500 pickup 4wd    5.2  1999    8  manual(m5)   4
# 73         dodge     ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4
# 74         dodge     ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4
# 75          ford          expedition 2wd    4.6  1999    8    auto(l4)   r
# 76          ford          expedition 2wd    5.4  1999    8    auto(l4)   r
# 77          ford          expedition 2wd    5.4  2008    8    auto(l6)   r
# 78          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 79          ford            explorer 4wd    4.0  1999    6  manual(m5)   4
# 80          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 81          ford            explorer 4wd    4.0  2008    6    auto(l5)   4
# 82          ford            explorer 4wd    4.6  2008    8    auto(l6)   4
# 83          ford            explorer 4wd    5.0  1999    8    auto(l4)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6    auto(l4)   4
# 85          ford         f150 pickup 4wd    4.2  1999    6  manual(m5)   4
# ..           ...                     ...    ...   ...  ...         ...  ..
# 150       nissan                  maxima    3.5  2008    6    auto(av)   f
# 151       nissan          pathfinder 4wd    3.3  1999    6    auto(l4)   4
# 152       nissan          pathfinder 4wd    3.3  1999    6  manual(m5)   4
# 153       nissan          pathfinder 4wd    4.0  2008    6    auto(l5)   4
# 154       nissan          pathfinder 4wd    5.6  2008    8    auto(s5)   4
# 155      pontiac              grand prix    3.1  1999    6    auto(l4)   f
# 156      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 157      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 158      pontiac              grand prix    3.8  2008    6    auto(l4)   f
# 159      pontiac              grand prix    5.3  2008    8    auto(s4)   f
# 160       subaru            forester awd    2.5  1999    4  manual(m5)   4
# 161       subaru            forester awd    2.5  1999    4    auto(l4)   4
# 162       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 163       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 164       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 165       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 166       subaru             impreza awd    2.2  1999    4    auto(l4)   4
# 167       subaru             impreza awd    2.2  1999    4  manual(m5)   4
# 168       subaru             impreza awd    2.5  1999    4  manual(m5)   4
# 169       subaru             impreza awd    2.5  1999    4    auto(l4)   4
# 170       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 171       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 172       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 173       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 174       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
# 175       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4
# 177       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 178       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 179       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 180       toyota                   camry    2.2  1999    4  manual(m5)   f
# 181       toyota                   camry    2.2  1999    4    auto(l4)   f
# 182       toyota                   camry    2.4  2008    4  manual(m5)   f
# 183       toyota                   camry    2.4  2008    4    auto(l5)   f
# 184       toyota                   camry    3.0  1999    6    auto(l4)   f
# 185       toyota                   camry    3.0  1999    6  manual(m5)   f
# 186       toyota                   camry    3.5  2008    6    auto(s6)   f
# 187       toyota            camry solara    2.2  1999    4    auto(l4)   f
# 188       toyota            camry solara    2.2  1999    4  manual(m5)   f
# 189       toyota            camry solara    2.4  2008    4  manual(m5)   f
# 190       toyota            camry solara    2.4  2008    4    auto(s5)   f
# 191       toyota            camry solara    3.0  1999    6    auto(l4)   f
# 192       toyota            camry solara    3.0  1999    6  manual(m5)   f
# 193       toyota            camry solara    3.3  2008    6    auto(s5)   f
# 194       toyota                 corolla    1.8  1999    4    auto(l3)   f
# 195       toyota                 corolla    1.8  1999    4    auto(l4)   f
# 196       toyota                 corolla    1.8  1999    4  manual(m5)   f
# 197       toyota                 corolla    1.8  2008    4  manual(m5)   f
# 198       toyota                 corolla    1.8  2008    4    auto(l4)   f
# 199       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 200       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4
# 201       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4
# 202       toyota       toyota tacoma 4wd    2.7  1999    4    auto(l4)   4
# 203       toyota       toyota tacoma 4wd    2.7  2008    4  manual(m5)   4
# 204       toyota       toyota tacoma 4wd    3.4  1999    6  manual(m5)   4
# 205       toyota       toyota tacoma 4wd    3.4  1999    6    auto(l4)   4
# 206       toyota       toyota tacoma 4wd    4.0  2008    6  manual(m6)   4
# 207       toyota       toyota tacoma 4wd    4.0  2008    6    auto(l5)   4
# 208   volkswagen                     gti    2.0  1999    4  manual(m5)   f
# 209   volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 210   volkswagen                     gti    2.0  2008    4  manual(m6)   f
# 211   volkswagen                     gti    2.0  2008    4    auto(s6)   f
# 212   volkswagen                     gti    2.8  1999    6  manual(m5)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 214   volkswagen                   jetta    2.0  1999    4  manual(m5)   f
# 215   volkswagen                   jetta    2.0  1999    4    auto(l4)   f
# 216   volkswagen                   jetta    2.0  2008    4    auto(s6)   f
# 217   volkswagen                   jetta    2.0  2008    4  manual(m6)   f
# 218   volkswagen                   jetta    2.5  2008    5    auto(s6)   f
# 219   volkswagen                   jetta    2.5  2008    5  manual(m5)   f
# 220   volkswagen                   jetta    2.8  1999    6    auto(l4)   f
# 221   volkswagen                   jetta    2.8  1999    6  manual(m5)   f
# 222   volkswagen              new beetle    1.9  1999    4  manual(m5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 224   volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 225   volkswagen              new beetle    2.0  1999    4    auto(l4)   f
# 226   volkswagen              new beetle    2.5  2008    5  manual(m5)   f
# 227   volkswagen              new beetle    2.5  2008    5    auto(s6)   f
# 228   volkswagen                  passat    1.8  1999    4  manual(m5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 230   volkswagen                  passat    2.0  2008    4    auto(s6)   f
# 231   volkswagen                  passat    2.0  2008    4  manual(m6)   f
# 232   volkswagen                  passat    2.8  1999    6    auto(l5)   f
# 233   volkswagen                  passat    2.8  1999    6  manual(m5)   f
# 234   volkswagen                  passat    3.6  2008    6    auto(s6)   f
#
#      city  hwy fl       class  mileage_difference  average_mileage
# 1      18   29  p     compact                  11               18
# 2      21   29  p     compact                   8               21
# 3      20   31  p     compact                  11               20
# 4      21   30  p     compact                   9               21
# 5      16   26  p     compact                  10               16
# 6      18   26  p     compact                   8               18
# 7      18   27  p     compact                   9               18
# 8      18   26  p     compact                   8               18
# 9      16   25  p     compact                   9               16
# 10     20   28  p     compact                   8               20
# 11     19   27  p     compact                   8               19
# 12     15   25  p     compact                  10               15
# 13     17   25  p     compact                   8               17
# 14     17   25  p     compact                   8               17
# 15     15   25  p     compact                  10               15
# 16     15   24  p     midsize                   9               15
# 17     17   25  p     midsize                   8               17
# 18     16   23  p     midsize                   7               16
# 19     14   20  r         suv                   6               14
# 20     11   15  e         suv                   4               11
# 21     14   20  r         suv                   6               14
# 22     13   17  r         suv                   4               13
# 23     12   17  r         suv                   5               12
# 24     16   26  p     2seater                  10               16
# 25     15   23  p     2seater                   8               15
# 26     16   26  p     2seater                  10               16
# 27     15   25  p     2seater                  10               15
# 28     15   24  p     2seater                   9               15
# 29     14   19  r         suv                   5               14
# 30     11   14  e         suv                   3               11
# 31     11   15  r         suv                   4               11
# 32     14   17  d         suv                   3               14
# 33     19   27  r     midsize                   8               19
# 34     22   30  r     midsize                   8               22
# 35     18   26  r     midsize                   8               18
# 36     18   29  r     midsize                  11               18
# 37     17   26  r     midsize                   9               17
# 38     18   24  r     minivan                   6               18
# 39     17   24  r     minivan                   7               17
# 40     16   22  r     minivan                   6               16
# 41     16   22  r     minivan                   6               16
# 42     17   24  r     minivan                   7               17
# 43     17   24  r     minivan                   7               17
# 44     11   17  e     minivan                   6               11
# 45     15   22  r     minivan                   7               15
# 46     15   21  r     minivan                   6               15
# 47     16   23  r     minivan                   7               16
# 48     16   23  r     minivan                   7               16
# 49     15   19  r      pickup                   4               15
# 50     14   18  r      pickup                   4               14
# 51     13   17  r      pickup                   4               13
# 52     14   17  r      pickup                   3               14
# 53     14   19  r      pickup                   5               14
# 54     14   19  r      pickup                   5               14
# 55      9   12  e      pickup                   3                9
# 56     11   17  r      pickup                   6               11
# 57     11   15  r      pickup                   4               11
# 58     13   17  r         suv                   4               13
# 59     13   17  r         suv                   4               13
# 60      9   12  e         suv                   3                9
# 61     13   17  r         suv                   4               13
# 62     11   16  r         suv                   5               11
# 63     13   18  r         suv                   5               13
# 64     11   15  r         suv                   4               11
# 65     12   16  r      pickup                   4               12
# 66      9   12  e      pickup                   3                9
# 67     13   17  r      pickup                   4               13
# 68     13   17  r      pickup                   4               13
# 69     12   16  r      pickup                   4               12
# 70      9   12  e      pickup                   3                9
# 71     11   15  r      pickup                   4               11
# 72     11   16  r      pickup                   5               11
# 73     13   17  r      pickup                   4               13
# 74     11   15  r      pickup                   4               11
# 75     11   17  r         suv                   6               11
# 76     11   17  r         suv                   6               11
# 77     12   18  r         suv                   6               12
# 78     14   17  r         suv                   3               14
# 79     15   19  r         suv                   4               15
# 80     14   17  r         suv                   3               14
# 81     13   19  r         suv                   6               13
# 82     13   19  r         suv                   6               13
# 83     13   17  r         suv                   4               13
# 84     14   17  r      pickup                   3               14
# 85     14   17  r      pickup                   3               14
# ..    ...  ... ..         ...                 ...              ...
# 150    19   25  p     midsize                   6               19
# 151    14   17  r         suv                   3               14
# 152    15   17  r         suv                   2               15
# 153    14   20  p         suv                   6               14
# 154    12   18  p         suv                   6               12
# 155    18   26  r     midsize                   8               18
# 156    16   26  p     midsize                  10               16
# 157    17   27  r     midsize                  10               17
# 158    18   28  r     midsize                  10               18
# 159    16   25  p     midsize                   9               16
# 160    18   25  r         suv                   7               18
# 161    18   24  r         suv                   6               18
# 162    20   27  r         suv                   7               20
# 163    19   25  p         suv                   6               19
# 164    20   26  r         suv                   6               20
# 165    18   23  p         suv                   5               18
# 166    21   26  r  subcompact                   5               21
# 167    19   26  r  subcompact                   7               19
# 168    19   26  r  subcompact                   7               19
# 169    19   26  r  subcompact                   7               19
# 170    20   25  p     compact                   5               20
# 171    20   27  r     compact                   7               20
# 172    19   25  p     compact                   6               19
# 173    20   27  r     compact                   7               20
# 174    15   20  r         suv                   5               15
# 175    16   20  r         suv                   4               16
# 176    15   19  r         suv                   4               15
# 177    15   17  r         suv                   2               15
# 178    16   20  r         suv                   4               16
# 179    14   17  r         suv                   3               14
# 180    21   29  r     midsize                   8               21
# 181    21   27  r     midsize                   6               21
# 182    21   31  r     midsize                  10               21
# 183    21   31  r     midsize                  10               21
# 184    18   26  r     midsize                   8               18
# 185    18   26  r     midsize                   8               18
# 186    19   28  r     midsize                   9               19
# 187    21   27  r     compact                   6               21
# 188    21   29  r     compact                   8               21
# 189    21   31  r     compact                  10               21
# 190    22   31  r     compact                   9               22
# 191    18   26  r     compact                   8               18
# 192    18   26  r     compact                   8               18
# 193    18   27  r     compact                   9               18
# 194    24   30  r     compact                   6               24
# 195    24   33  r     compact                   9               24
# 196    26   35  r     compact                   9               26
# 197    28   37  r     compact                   9               28
# 198    26   35  r     compact                   9               26
# 199    11   15  r         suv                   4               11
# 200    13   18  r         suv                   5               13
# 201    15   20  r      pickup                   5               15
# 202    16   20  r      pickup                   4               16
# 203    17   22  r      pickup                   5               17
# 204    15   17  r      pickup                   2               15
# 205    15   19  r      pickup                   4               15
# 206    15   18  r      pickup                   3               15
# 207    16   20  r      pickup                   4               16
# 208    21   29  r     compact                   8               21
# 209    19   26  r     compact                   7               19
# 210    21   29  p     compact                   8               21
# 211    22   29  p     compact                   7               22
# 212    17   24  r     compact                   7               17
# 213    33   44  d     compact                  11               33
# 214    21   29  r     compact                   8               21
# 215    19   26  r     compact                   7               19
# 216    22   29  p     compact                   7               22
# 217    21   29  p     compact                   8               21
# 218    21   29  r     compact                   8               21
# 219    21   29  r     compact                   8               21
# 220    16   23  r     compact                   7               16
# 221    17   24  r     compact                   7               17
# 222    35   44  d  subcompact                   9               35
# 223    29   41  d  subcompact                  12               29
# 224    21   29  r  subcompact                   8               21
# 225    19   26  r  subcompact                   7               19
# 226    20   28  r  subcompact                   8               20
# 227    20   29  r  subcompact                   9               20
# 228    21   29  p     midsize                   8               21
# 229    18   29  p     midsize                  11               18
# 230    19   28  p     midsize                   9               19
# 231    21   29  p     midsize                   8               21
# 232    16   26  p     midsize                  10               16
# 233    18   26  p     midsize                   8               18
# 234    17   26  p     midsize                   9               17
#
# [234 rows x 13 columns]

# %%
#E. Rename the hwy column to highway.
mpg.rename(columns={'hwy' : 'highway'})
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 13          audi              a4 quattro    2.8  1999    6  manual(m5)   4
# 14          audi              a4 quattro    3.1  2008    6    auto(s6)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8    auto(s6)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 25     chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 26     chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 27     chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 28     chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 30     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 31     chevrolet         k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 33     chevrolet                  malibu    2.4  1999    4    auto(l4)   f
# 34     chevrolet                  malibu    2.4  2008    4    auto(l4)   f
# 35     chevrolet                  malibu    3.1  1999    6    auto(l4)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 37     chevrolet                  malibu    3.6  2008    6    auto(s6)   f
# 38         dodge             caravan 2wd    2.4  1999    4    auto(l3)   f
# 39         dodge             caravan 2wd    3.0  1999    6    auto(l4)   f
# 40         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 41         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 42         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 43         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 44         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 45         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 46         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 47         dodge             caravan 2wd    3.8  2008    6    auto(l6)   f
# 48         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 49         dodge       dakota pickup 4wd    3.7  2008    6  manual(m6)   4
# 50         dodge       dakota pickup 4wd    3.7  2008    6    auto(l4)   4
# 51         dodge       dakota pickup 4wd    3.9  1999    6    auto(l4)   4
# 52         dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 53         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 54         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 55         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 56         dodge       dakota pickup 4wd    5.2  1999    8  manual(m5)   4
# 57         dodge       dakota pickup 4wd    5.2  1999    8    auto(l4)   4
# 58         dodge             durango 4wd    3.9  1999    6    auto(l4)   4
# 59         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 60         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 61         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 62         dodge             durango 4wd    5.2  1999    8    auto(l4)   4
# 63         dodge             durango 4wd    5.7  2008    8    auto(l5)   4
# 64         dodge             durango 4wd    5.9  1999    8    auto(l4)   4
# 65         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 69         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 70         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 71         dodge     ram 1500 pickup 4wd    5.2  1999    8    auto(l4)   4
# 72         dodge     ram 1500 pickup 4wd    5.2  1999    8  manual(m5)   4
# 73         dodge     ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4
# 74         dodge     ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4
# 75          ford          expedition 2wd    4.6  1999    8    auto(l4)   r
# 76          ford          expedition 2wd    5.4  1999    8    auto(l4)   r
# 77          ford          expedition 2wd    5.4  2008    8    auto(l6)   r
# 78          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 79          ford            explorer 4wd    4.0  1999    6  manual(m5)   4
# 80          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 81          ford            explorer 4wd    4.0  2008    6    auto(l5)   4
# 82          ford            explorer 4wd    4.6  2008    8    auto(l6)   4
# 83          ford            explorer 4wd    5.0  1999    8    auto(l4)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6    auto(l4)   4
# 85          ford         f150 pickup 4wd    4.2  1999    6  manual(m5)   4
# ..           ...                     ...    ...   ...  ...         ...  ..
# 150       nissan                  maxima    3.5  2008    6    auto(av)   f
# 151       nissan          pathfinder 4wd    3.3  1999    6    auto(l4)   4
# 152       nissan          pathfinder 4wd    3.3  1999    6  manual(m5)   4
# 153       nissan          pathfinder 4wd    4.0  2008    6    auto(l5)   4
# 154       nissan          pathfinder 4wd    5.6  2008    8    auto(s5)   4
# 155      pontiac              grand prix    3.1  1999    6    auto(l4)   f
# 156      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 157      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 158      pontiac              grand prix    3.8  2008    6    auto(l4)   f
# 159      pontiac              grand prix    5.3  2008    8    auto(s4)   f
# 160       subaru            forester awd    2.5  1999    4  manual(m5)   4
# 161       subaru            forester awd    2.5  1999    4    auto(l4)   4
# 162       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 163       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 164       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 165       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 166       subaru             impreza awd    2.2  1999    4    auto(l4)   4
# 167       subaru             impreza awd    2.2  1999    4  manual(m5)   4
# 168       subaru             impreza awd    2.5  1999    4  manual(m5)   4
# 169       subaru             impreza awd    2.5  1999    4    auto(l4)   4
# 170       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 171       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 172       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 173       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 174       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
# 175       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4
# 177       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 178       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 179       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 180       toyota                   camry    2.2  1999    4  manual(m5)   f
# 181       toyota                   camry    2.2  1999    4    auto(l4)   f
# 182       toyota                   camry    2.4  2008    4  manual(m5)   f
# 183       toyota                   camry    2.4  2008    4    auto(l5)   f
# 184       toyota                   camry    3.0  1999    6    auto(l4)   f
# 185       toyota                   camry    3.0  1999    6  manual(m5)   f
# 186       toyota                   camry    3.5  2008    6    auto(s6)   f
# 187       toyota            camry solara    2.2  1999    4    auto(l4)   f
# 188       toyota            camry solara    2.2  1999    4  manual(m5)   f
# 189       toyota            camry solara    2.4  2008    4  manual(m5)   f
# 190       toyota            camry solara    2.4  2008    4    auto(s5)   f
# 191       toyota            camry solara    3.0  1999    6    auto(l4)   f
# 192       toyota            camry solara    3.0  1999    6  manual(m5)   f
# 193       toyota            camry solara    3.3  2008    6    auto(s5)   f
# 194       toyota                 corolla    1.8  1999    4    auto(l3)   f
# 195       toyota                 corolla    1.8  1999    4    auto(l4)   f
# 196       toyota                 corolla    1.8  1999    4  manual(m5)   f
# 197       toyota                 corolla    1.8  2008    4  manual(m5)   f
# 198       toyota                 corolla    1.8  2008    4    auto(l4)   f
# 199       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 200       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4
# 201       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4
# 202       toyota       toyota tacoma 4wd    2.7  1999    4    auto(l4)   4
# 203       toyota       toyota tacoma 4wd    2.7  2008    4  manual(m5)   4
# 204       toyota       toyota tacoma 4wd    3.4  1999    6  manual(m5)   4
# 205       toyota       toyota tacoma 4wd    3.4  1999    6    auto(l4)   4
# 206       toyota       toyota tacoma 4wd    4.0  2008    6  manual(m6)   4
# 207       toyota       toyota tacoma 4wd    4.0  2008    6    auto(l5)   4
# 208   volkswagen                     gti    2.0  1999    4  manual(m5)   f
# 209   volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 210   volkswagen                     gti    2.0  2008    4  manual(m6)   f
# 211   volkswagen                     gti    2.0  2008    4    auto(s6)   f
# 212   volkswagen                     gti    2.8  1999    6  manual(m5)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 214   volkswagen                   jetta    2.0  1999    4  manual(m5)   f
# 215   volkswagen                   jetta    2.0  1999    4    auto(l4)   f
# 216   volkswagen                   jetta    2.0  2008    4    auto(s6)   f
# 217   volkswagen                   jetta    2.0  2008    4  manual(m6)   f
# 218   volkswagen                   jetta    2.5  2008    5    auto(s6)   f
# 219   volkswagen                   jetta    2.5  2008    5  manual(m5)   f
# 220   volkswagen                   jetta    2.8  1999    6    auto(l4)   f
# 221   volkswagen                   jetta    2.8  1999    6  manual(m5)   f
# 222   volkswagen              new beetle    1.9  1999    4  manual(m5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 224   volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 225   volkswagen              new beetle    2.0  1999    4    auto(l4)   f
# 226   volkswagen              new beetle    2.5  2008    5  manual(m5)   f
# 227   volkswagen              new beetle    2.5  2008    5    auto(s6)   f
# 228   volkswagen                  passat    1.8  1999    4  manual(m5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 230   volkswagen                  passat    2.0  2008    4    auto(s6)   f
# 231   volkswagen                  passat    2.0  2008    4  manual(m6)   f
# 232   volkswagen                  passat    2.8  1999    6    auto(l5)   f
# 233   volkswagen                  passat    2.8  1999    6  manual(m5)   f
# 234   volkswagen                  passat    3.6  2008    6    auto(s6)   f
#
#      cty  highway fl       class  mileage_difference  average_mileage
# 1     18       29  p     compact                  11               18
# 2     21       29  p     compact                   8               21
# 3     20       31  p     compact                  11               20
# 4     21       30  p     compact                   9               21
# 5     16       26  p     compact                  10               16
# 6     18       26  p     compact                   8               18
# 7     18       27  p     compact                   9               18
# 8     18       26  p     compact                   8               18
# 9     16       25  p     compact                   9               16
# 10    20       28  p     compact                   8               20
# 11    19       27  p     compact                   8               19
# 12    15       25  p     compact                  10               15
# 13    17       25  p     compact                   8               17
# 14    17       25  p     compact                   8               17
# 15    15       25  p     compact                  10               15
# 16    15       24  p     midsize                   9               15
# 17    17       25  p     midsize                   8               17
# 18    16       23  p     midsize                   7               16
# 19    14       20  r         suv                   6               14
# 20    11       15  e         suv                   4               11
# 21    14       20  r         suv                   6               14
# 22    13       17  r         suv                   4               13
# 23    12       17  r         suv                   5               12
# 24    16       26  p     2seater                  10               16
# 25    15       23  p     2seater                   8               15
# 26    16       26  p     2seater                  10               16
# 27    15       25  p     2seater                  10               15
# 28    15       24  p     2seater                   9               15
# 29    14       19  r         suv                   5               14
# 30    11       14  e         suv                   3               11
# 31    11       15  r         suv                   4               11
# 32    14       17  d         suv                   3               14
# 33    19       27  r     midsize                   8               19
# 34    22       30  r     midsize                   8               22
# 35    18       26  r     midsize                   8               18
# 36    18       29  r     midsize                  11               18
# 37    17       26  r     midsize                   9               17
# 38    18       24  r     minivan                   6               18
# 39    17       24  r     minivan                   7               17
# 40    16       22  r     minivan                   6               16
# 41    16       22  r     minivan                   6               16
# 42    17       24  r     minivan                   7               17
# 43    17       24  r     minivan                   7               17
# 44    11       17  e     minivan                   6               11
# 45    15       22  r     minivan                   7               15
# 46    15       21  r     minivan                   6               15
# 47    16       23  r     minivan                   7               16
# 48    16       23  r     minivan                   7               16
# 49    15       19  r      pickup                   4               15
# 50    14       18  r      pickup                   4               14
# 51    13       17  r      pickup                   4               13
# 52    14       17  r      pickup                   3               14
# 53    14       19  r      pickup                   5               14
# 54    14       19  r      pickup                   5               14
# 55     9       12  e      pickup                   3                9
# 56    11       17  r      pickup                   6               11
# 57    11       15  r      pickup                   4               11
# 58    13       17  r         suv                   4               13
# 59    13       17  r         suv                   4               13
# 60     9       12  e         suv                   3                9
# 61    13       17  r         suv                   4               13
# 62    11       16  r         suv                   5               11
# 63    13       18  r         suv                   5               13
# 64    11       15  r         suv                   4               11
# 65    12       16  r      pickup                   4               12
# 66     9       12  e      pickup                   3                9
# 67    13       17  r      pickup                   4               13
# 68    13       17  r      pickup                   4               13
# 69    12       16  r      pickup                   4               12
# 70     9       12  e      pickup                   3                9
# 71    11       15  r      pickup                   4               11
# 72    11       16  r      pickup                   5               11
# 73    13       17  r      pickup                   4               13
# 74    11       15  r      pickup                   4               11
# 75    11       17  r         suv                   6               11
# 76    11       17  r         suv                   6               11
# 77    12       18  r         suv                   6               12
# 78    14       17  r         suv                   3               14
# 79    15       19  r         suv                   4               15
# 80    14       17  r         suv                   3               14
# 81    13       19  r         suv                   6               13
# 82    13       19  r         suv                   6               13
# 83    13       17  r         suv                   4               13
# 84    14       17  r      pickup                   3               14
# 85    14       17  r      pickup                   3               14
# ..   ...      ... ..         ...                 ...              ...
# 150   19       25  p     midsize                   6               19
# 151   14       17  r         suv                   3               14
# 152   15       17  r         suv                   2               15
# 153   14       20  p         suv                   6               14
# 154   12       18  p         suv                   6               12
# 155   18       26  r     midsize                   8               18
# 156   16       26  p     midsize                  10               16
# 157   17       27  r     midsize                  10               17
# 158   18       28  r     midsize                  10               18
# 159   16       25  p     midsize                   9               16
# 160   18       25  r         suv                   7               18
# 161   18       24  r         suv                   6               18
# 162   20       27  r         suv                   7               20
# 163   19       25  p         suv                   6               19
# 164   20       26  r         suv                   6               20
# 165   18       23  p         suv                   5               18
# 166   21       26  r  subcompact                   5               21
# 167   19       26  r  subcompact                   7               19
# 168   19       26  r  subcompact                   7               19
# 169   19       26  r  subcompact                   7               19
# 170   20       25  p     compact                   5               20
# 171   20       27  r     compact                   7               20
# 172   19       25  p     compact                   6               19
# 173   20       27  r     compact                   7               20
# 174   15       20  r         suv                   5               15
# 175   16       20  r         suv                   4               16
# 176   15       19  r         suv                   4               15
# 177   15       17  r         suv                   2               15
# 178   16       20  r         suv                   4               16
# 179   14       17  r         suv                   3               14
# 180   21       29  r     midsize                   8               21
# 181   21       27  r     midsize                   6               21
# 182   21       31  r     midsize                  10               21
# 183   21       31  r     midsize                  10               21
# 184   18       26  r     midsize                   8               18
# 185   18       26  r     midsize                   8               18
# 186   19       28  r     midsize                   9               19
# 187   21       27  r     compact                   6               21
# 188   21       29  r     compact                   8               21
# 189   21       31  r     compact                  10               21
# 190   22       31  r     compact                   9               22
# 191   18       26  r     compact                   8               18
# 192   18       26  r     compact                   8               18
# 193   18       27  r     compact                   9               18
# 194   24       30  r     compact                   6               24
# 195   24       33  r     compact                   9               24
# 196   26       35  r     compact                   9               26
# 197   28       37  r     compact                   9               28
# 198   26       35  r     compact                   9               26
# 199   11       15  r         suv                   4               11
# 200   13       18  r         suv                   5               13
# 201   15       20  r      pickup                   5               15
# 202   16       20  r      pickup                   4               16
# 203   17       22  r      pickup                   5               17
# 204   15       17  r      pickup                   2               15
# 205   15       19  r      pickup                   4               15
# 206   15       18  r      pickup                   3               15
# 207   16       20  r      pickup                   4               16
# 208   21       29  r     compact                   8               21
# 209   19       26  r     compact                   7               19
# 210   21       29  p     compact                   8               21
# 211   22       29  p     compact                   7               22
# 212   17       24  r     compact                   7               17
# 213   33       44  d     compact                  11               33
# 214   21       29  r     compact                   8               21
# 215   19       26  r     compact                   7               19
# 216   22       29  p     compact                   7               22
# 217   21       29  p     compact                   8               21
# 218   21       29  r     compact                   8               21
# 219   21       29  r     compact                   8               21
# 220   16       23  r     compact                   7               16
# 221   17       24  r     compact                   7               17
# 222   35       44  d  subcompact                   9               35
# 223   29       41  d  subcompact                  12               29
# 224   21       29  r  subcompact                   8               21
# 225   19       26  r  subcompact                   7               19
# 226   20       28  r  subcompact                   8               20
# 227   20       29  r  subcompact                   9               20
# 228   21       29  p     midsize                   8               21
# 229   18       29  p     midsize                  11               18
# 230   19       28  p     midsize                   9               19
# 231   21       29  p     midsize                   8               21
# 232   16       26  p     midsize                  10               16
# 233   18       26  p     midsize                   8               18
# 234   17       26  p     midsize                   9               17
#
# [234 rows x 13 columns]

# %%
#F. Do any cars have better city mileage than highway mileage?
better = mpg.hwy < mpg.cty
mpg[better]
# no cars have a better city mileage than highway mileage
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, cty, hwy, fl, class, mileage_difference, average_mileage]
# Index: []

# %%
#G. Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.
mpg['mileage_difference'] = mpg.hwy - mpg.cty
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 13          audi              a4 quattro    2.8  1999    6  manual(m5)   4
# 14          audi              a4 quattro    3.1  2008    6    auto(s6)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8    auto(s6)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 25     chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 26     chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 27     chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 28     chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 30     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 31     chevrolet         k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 33     chevrolet                  malibu    2.4  1999    4    auto(l4)   f
# 34     chevrolet                  malibu    2.4  2008    4    auto(l4)   f
# 35     chevrolet                  malibu    3.1  1999    6    auto(l4)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 37     chevrolet                  malibu    3.6  2008    6    auto(s6)   f
# 38         dodge             caravan 2wd    2.4  1999    4    auto(l3)   f
# 39         dodge             caravan 2wd    3.0  1999    6    auto(l4)   f
# 40         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 41         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 42         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 43         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 44         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 45         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 46         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 47         dodge             caravan 2wd    3.8  2008    6    auto(l6)   f
# 48         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 49         dodge       dakota pickup 4wd    3.7  2008    6  manual(m6)   4
# 50         dodge       dakota pickup 4wd    3.7  2008    6    auto(l4)   4
# 51         dodge       dakota pickup 4wd    3.9  1999    6    auto(l4)   4
# 52         dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 53         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 54         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 55         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 56         dodge       dakota pickup 4wd    5.2  1999    8  manual(m5)   4
# 57         dodge       dakota pickup 4wd    5.2  1999    8    auto(l4)   4
# 58         dodge             durango 4wd    3.9  1999    6    auto(l4)   4
# 59         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 60         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 61         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 62         dodge             durango 4wd    5.2  1999    8    auto(l4)   4
# 63         dodge             durango 4wd    5.7  2008    8    auto(l5)   4
# 64         dodge             durango 4wd    5.9  1999    8    auto(l4)   4
# 65         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 69         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 70         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 71         dodge     ram 1500 pickup 4wd    5.2  1999    8    auto(l4)   4
# 72         dodge     ram 1500 pickup 4wd    5.2  1999    8  manual(m5)   4
# 73         dodge     ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4
# 74         dodge     ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4
# 75          ford          expedition 2wd    4.6  1999    8    auto(l4)   r
# 76          ford          expedition 2wd    5.4  1999    8    auto(l4)   r
# 77          ford          expedition 2wd    5.4  2008    8    auto(l6)   r
# 78          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 79          ford            explorer 4wd    4.0  1999    6  manual(m5)   4
# 80          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 81          ford            explorer 4wd    4.0  2008    6    auto(l5)   4
# 82          ford            explorer 4wd    4.6  2008    8    auto(l6)   4
# 83          ford            explorer 4wd    5.0  1999    8    auto(l4)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6    auto(l4)   4
# 85          ford         f150 pickup 4wd    4.2  1999    6  manual(m5)   4
# ..           ...                     ...    ...   ...  ...         ...  ..
# 150       nissan                  maxima    3.5  2008    6    auto(av)   f
# 151       nissan          pathfinder 4wd    3.3  1999    6    auto(l4)   4
# 152       nissan          pathfinder 4wd    3.3  1999    6  manual(m5)   4
# 153       nissan          pathfinder 4wd    4.0  2008    6    auto(l5)   4
# 154       nissan          pathfinder 4wd    5.6  2008    8    auto(s5)   4
# 155      pontiac              grand prix    3.1  1999    6    auto(l4)   f
# 156      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 157      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 158      pontiac              grand prix    3.8  2008    6    auto(l4)   f
# 159      pontiac              grand prix    5.3  2008    8    auto(s4)   f
# 160       subaru            forester awd    2.5  1999    4  manual(m5)   4
# 161       subaru            forester awd    2.5  1999    4    auto(l4)   4
# 162       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 163       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 164       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 165       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 166       subaru             impreza awd    2.2  1999    4    auto(l4)   4
# 167       subaru             impreza awd    2.2  1999    4  manual(m5)   4
# 168       subaru             impreza awd    2.5  1999    4  manual(m5)   4
# 169       subaru             impreza awd    2.5  1999    4    auto(l4)   4
# 170       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 171       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 172       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 173       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 174       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
# 175       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4
# 177       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 178       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 179       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 180       toyota                   camry    2.2  1999    4  manual(m5)   f
# 181       toyota                   camry    2.2  1999    4    auto(l4)   f
# 182       toyota                   camry    2.4  2008    4  manual(m5)   f
# 183       toyota                   camry    2.4  2008    4    auto(l5)   f
# 184       toyota                   camry    3.0  1999    6    auto(l4)   f
# 185       toyota                   camry    3.0  1999    6  manual(m5)   f
# 186       toyota                   camry    3.5  2008    6    auto(s6)   f
# 187       toyota            camry solara    2.2  1999    4    auto(l4)   f
# 188       toyota            camry solara    2.2  1999    4  manual(m5)   f
# 189       toyota            camry solara    2.4  2008    4  manual(m5)   f
# 190       toyota            camry solara    2.4  2008    4    auto(s5)   f
# 191       toyota            camry solara    3.0  1999    6    auto(l4)   f
# 192       toyota            camry solara    3.0  1999    6  manual(m5)   f
# 193       toyota            camry solara    3.3  2008    6    auto(s5)   f
# 194       toyota                 corolla    1.8  1999    4    auto(l3)   f
# 195       toyota                 corolla    1.8  1999    4    auto(l4)   f
# 196       toyota                 corolla    1.8  1999    4  manual(m5)   f
# 197       toyota                 corolla    1.8  2008    4  manual(m5)   f
# 198       toyota                 corolla    1.8  2008    4    auto(l4)   f
# 199       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 200       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4
# 201       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4
# 202       toyota       toyota tacoma 4wd    2.7  1999    4    auto(l4)   4
# 203       toyota       toyota tacoma 4wd    2.7  2008    4  manual(m5)   4
# 204       toyota       toyota tacoma 4wd    3.4  1999    6  manual(m5)   4
# 205       toyota       toyota tacoma 4wd    3.4  1999    6    auto(l4)   4
# 206       toyota       toyota tacoma 4wd    4.0  2008    6  manual(m6)   4
# 207       toyota       toyota tacoma 4wd    4.0  2008    6    auto(l5)   4
# 208   volkswagen                     gti    2.0  1999    4  manual(m5)   f
# 209   volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 210   volkswagen                     gti    2.0  2008    4  manual(m6)   f
# 211   volkswagen                     gti    2.0  2008    4    auto(s6)   f
# 212   volkswagen                     gti    2.8  1999    6  manual(m5)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 214   volkswagen                   jetta    2.0  1999    4  manual(m5)   f
# 215   volkswagen                   jetta    2.0  1999    4    auto(l4)   f
# 216   volkswagen                   jetta    2.0  2008    4    auto(s6)   f
# 217   volkswagen                   jetta    2.0  2008    4  manual(m6)   f
# 218   volkswagen                   jetta    2.5  2008    5    auto(s6)   f
# 219   volkswagen                   jetta    2.5  2008    5  manual(m5)   f
# 220   volkswagen                   jetta    2.8  1999    6    auto(l4)   f
# 221   volkswagen                   jetta    2.8  1999    6  manual(m5)   f
# 222   volkswagen              new beetle    1.9  1999    4  manual(m5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 224   volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 225   volkswagen              new beetle    2.0  1999    4    auto(l4)   f
# 226   volkswagen              new beetle    2.5  2008    5  manual(m5)   f
# 227   volkswagen              new beetle    2.5  2008    5    auto(s6)   f
# 228   volkswagen                  passat    1.8  1999    4  manual(m5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 230   volkswagen                  passat    2.0  2008    4    auto(s6)   f
# 231   volkswagen                  passat    2.0  2008    4  manual(m6)   f
# 232   volkswagen                  passat    2.8  1999    6    auto(l5)   f
# 233   volkswagen                  passat    2.8  1999    6  manual(m5)   f
# 234   volkswagen                  passat    3.6  2008    6    auto(s6)   f
#
#      cty  hwy fl       class  mileage_difference
# 1     18   29  p     compact                  11
# 2     21   29  p     compact                   8
# 3     20   31  p     compact                  11
# 4     21   30  p     compact                   9
# 5     16   26  p     compact                  10
# 6     18   26  p     compact                   8
# 7     18   27  p     compact                   9
# 8     18   26  p     compact                   8
# 9     16   25  p     compact                   9
# 10    20   28  p     compact                   8
# 11    19   27  p     compact                   8
# 12    15   25  p     compact                  10
# 13    17   25  p     compact                   8
# 14    17   25  p     compact                   8
# 15    15   25  p     compact                  10
# 16    15   24  p     midsize                   9
# 17    17   25  p     midsize                   8
# 18    16   23  p     midsize                   7
# 19    14   20  r         suv                   6
# 20    11   15  e         suv                   4
# 21    14   20  r         suv                   6
# 22    13   17  r         suv                   4
# 23    12   17  r         suv                   5
# 24    16   26  p     2seater                  10
# 25    15   23  p     2seater                   8
# 26    16   26  p     2seater                  10
# 27    15   25  p     2seater                  10
# 28    15   24  p     2seater                   9
# 29    14   19  r         suv                   5
# 30    11   14  e         suv                   3
# 31    11   15  r         suv                   4
# 32    14   17  d         suv                   3
# 33    19   27  r     midsize                   8
# 34    22   30  r     midsize                   8
# 35    18   26  r     midsize                   8
# 36    18   29  r     midsize                  11
# 37    17   26  r     midsize                   9
# 38    18   24  r     minivan                   6
# 39    17   24  r     minivan                   7
# 40    16   22  r     minivan                   6
# 41    16   22  r     minivan                   6
# 42    17   24  r     minivan                   7
# 43    17   24  r     minivan                   7
# 44    11   17  e     minivan                   6
# 45    15   22  r     minivan                   7
# 46    15   21  r     minivan                   6
# 47    16   23  r     minivan                   7
# 48    16   23  r     minivan                   7
# 49    15   19  r      pickup                   4
# 50    14   18  r      pickup                   4
# 51    13   17  r      pickup                   4
# 52    14   17  r      pickup                   3
# 53    14   19  r      pickup                   5
# 54    14   19  r      pickup                   5
# 55     9   12  e      pickup                   3
# 56    11   17  r      pickup                   6
# 57    11   15  r      pickup                   4
# 58    13   17  r         suv                   4
# 59    13   17  r         suv                   4
# 60     9   12  e         suv                   3
# 61    13   17  r         suv                   4
# 62    11   16  r         suv                   5
# 63    13   18  r         suv                   5
# 64    11   15  r         suv                   4
# 65    12   16  r      pickup                   4
# 66     9   12  e      pickup                   3
# 67    13   17  r      pickup                   4
# 68    13   17  r      pickup                   4
# 69    12   16  r      pickup                   4
# 70     9   12  e      pickup                   3
# 71    11   15  r      pickup                   4
# 72    11   16  r      pickup                   5
# 73    13   17  r      pickup                   4
# 74    11   15  r      pickup                   4
# 75    11   17  r         suv                   6
# 76    11   17  r         suv                   6
# 77    12   18  r         suv                   6
# 78    14   17  r         suv                   3
# 79    15   19  r         suv                   4
# 80    14   17  r         suv                   3
# 81    13   19  r         suv                   6
# 82    13   19  r         suv                   6
# 83    13   17  r         suv                   4
# 84    14   17  r      pickup                   3
# 85    14   17  r      pickup                   3
# ..   ...  ... ..         ...                 ...
# 150   19   25  p     midsize                   6
# 151   14   17  r         suv                   3
# 152   15   17  r         suv                   2
# 153   14   20  p         suv                   6
# 154   12   18  p         suv                   6
# 155   18   26  r     midsize                   8
# 156   16   26  p     midsize                  10
# 157   17   27  r     midsize                  10
# 158   18   28  r     midsize                  10
# 159   16   25  p     midsize                   9
# 160   18   25  r         suv                   7
# 161   18   24  r         suv                   6
# 162   20   27  r         suv                   7
# 163   19   25  p         suv                   6
# 164   20   26  r         suv                   6
# 165   18   23  p         suv                   5
# 166   21   26  r  subcompact                   5
# 167   19   26  r  subcompact                   7
# 168   19   26  r  subcompact                   7
# 169   19   26  r  subcompact                   7
# 170   20   25  p     compact                   5
# 171   20   27  r     compact                   7
# 172   19   25  p     compact                   6
# 173   20   27  r     compact                   7
# 174   15   20  r         suv                   5
# 175   16   20  r         suv                   4
# 176   15   19  r         suv                   4
# 177   15   17  r         suv                   2
# 178   16   20  r         suv                   4
# 179   14   17  r         suv                   3
# 180   21   29  r     midsize                   8
# 181   21   27  r     midsize                   6
# 182   21   31  r     midsize                  10
# 183   21   31  r     midsize                  10
# 184   18   26  r     midsize                   8
# 185   18   26  r     midsize                   8
# 186   19   28  r     midsize                   9
# 187   21   27  r     compact                   6
# 188   21   29  r     compact                   8
# 189   21   31  r     compact                  10
# 190   22   31  r     compact                   9
# 191   18   26  r     compact                   8
# 192   18   26  r     compact                   8
# 193   18   27  r     compact                   9
# 194   24   30  r     compact                   6
# 195   24   33  r     compact                   9
# 196   26   35  r     compact                   9
# 197   28   37  r     compact                   9
# 198   26   35  r     compact                   9
# 199   11   15  r         suv                   4
# 200   13   18  r         suv                   5
# 201   15   20  r      pickup                   5
# 202   16   20  r      pickup                   4
# 203   17   22  r      pickup                   5
# 204   15   17  r      pickup                   2
# 205   15   19  r      pickup                   4
# 206   15   18  r      pickup                   3
# 207   16   20  r      pickup                   4
# 208   21   29  r     compact                   8
# 209   19   26  r     compact                   7
# 210   21   29  p     compact                   8
# 211   22   29  p     compact                   7
# 212   17   24  r     compact                   7
# 213   33   44  d     compact                  11
# 214   21   29  r     compact                   8
# 215   19   26  r     compact                   7
# 216   22   29  p     compact                   7
# 217   21   29  p     compact                   8
# 218   21   29  r     compact                   8
# 219   21   29  r     compact                   8
# 220   16   23  r     compact                   7
# 221   17   24  r     compact                   7
# 222   35   44  d  subcompact                   9
# 223   29   41  d  subcompact                  12
# 224   21   29  r  subcompact                   8
# 225   19   26  r  subcompact                   7
# 226   20   28  r  subcompact                   8
# 227   20   29  r  subcompact                   9
# 228   21   29  p     midsize                   8
# 229   18   29  p     midsize                  11
# 230   19   28  p     midsize                   9
# 231   21   29  p     midsize                   8
# 232   16   26  p     midsize                  10
# 233   18   26  p     midsize                   8
# 234   17   26  p     midsize                   9
#
# [234 rows x 12 columns]

# %%
##H. Which car (or cars) has the highest mileage difference?
mpg.mileage_difference.max()
mpg.sort_values(by='mileage_difference', ascending=False).head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  cty  hwy fl  \
# 107        honda  civic    1.8  2008    4  auto(l5)   f   24   36  c
#
#           class  mileage_difference  average_mileage
# 107  subcompact                  12               24

# %%
#I. Which compact class car has the lowest highway mileage? The best?
mpg[mpg['class'] == 'compact'].sort_values(by='hwy',ascending=True).head(1)
mpg[mpg['class'] == 'compact'].sort_values(by='hwy',ascending=True).tail(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f   33   44  d
#
#        class  mileage_difference  average_mileage
# 213  compact                  11               33

# %%
#J. Create a column named average_mileage that is the mean of the city and highway mileage.
mpg['average_mileage'] = mpg[['cty', 'hwy']].apply(np.mean,axis=1)
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6    auto(l5)   4
# 13          audi              a4 quattro    2.8  1999    6  manual(m5)   4
# 14          audi              a4 quattro    3.1  2008    6    auto(s6)   4
# 15          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    2.8  1999    6    auto(l5)   4
# 17          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# 18          audi              a6 quattro    4.2  2008    8    auto(s6)   4
# 19     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 21     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 22     chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r
# 23     chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 25     chevrolet                corvette    5.7  1999    8    auto(l4)   r
# 26     chevrolet                corvette    6.2  2008    8  manual(m6)   r
# 27     chevrolet                corvette    6.2  2008    8    auto(s6)   r
# 28     chevrolet                corvette    7.0  2008    8  manual(m6)   r
# 29     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 30     chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4
# 31     chevrolet         k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4
# 32     chevrolet         k1500 tahoe 4wd    6.5  1999    8    auto(l4)   4
# 33     chevrolet                  malibu    2.4  1999    4    auto(l4)   f
# 34     chevrolet                  malibu    2.4  2008    4    auto(l4)   f
# 35     chevrolet                  malibu    3.1  1999    6    auto(l4)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 37     chevrolet                  malibu    3.6  2008    6    auto(s6)   f
# 38         dodge             caravan 2wd    2.4  1999    4    auto(l3)   f
# 39         dodge             caravan 2wd    3.0  1999    6    auto(l4)   f
# 40         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 41         dodge             caravan 2wd    3.3  1999    6    auto(l4)   f
# 42         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 43         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 44         dodge             caravan 2wd    3.3  2008    6    auto(l4)   f
# 45         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 46         dodge             caravan 2wd    3.8  1999    6    auto(l4)   f
# 47         dodge             caravan 2wd    3.8  2008    6    auto(l6)   f
# 48         dodge             caravan 2wd    4.0  2008    6    auto(l6)   f
# 49         dodge       dakota pickup 4wd    3.7  2008    6  manual(m6)   4
# 50         dodge       dakota pickup 4wd    3.7  2008    6    auto(l4)   4
# 51         dodge       dakota pickup 4wd    3.9  1999    6    auto(l4)   4
# 52         dodge       dakota pickup 4wd    3.9  1999    6  manual(m5)   4
# 53         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 54         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 55         dodge       dakota pickup 4wd    4.7  2008    8    auto(l5)   4
# 56         dodge       dakota pickup 4wd    5.2  1999    8  manual(m5)   4
# 57         dodge       dakota pickup 4wd    5.2  1999    8    auto(l4)   4
# 58         dodge             durango 4wd    3.9  1999    6    auto(l4)   4
# 59         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 60         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 61         dodge             durango 4wd    4.7  2008    8    auto(l5)   4
# 62         dodge             durango 4wd    5.2  1999    8    auto(l4)   4
# 63         dodge             durango 4wd    5.7  2008    8    auto(l5)   4
# 64         dodge             durango 4wd    5.9  1999    8    auto(l4)   4
# 65         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 66         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 67         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 68         dodge     ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4
# 69         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 70         dodge     ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4
# 71         dodge     ram 1500 pickup 4wd    5.2  1999    8    auto(l4)   4
# 72         dodge     ram 1500 pickup 4wd    5.2  1999    8  manual(m5)   4
# 73         dodge     ram 1500 pickup 4wd    5.7  2008    8    auto(l5)   4
# 74         dodge     ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4
# 75          ford          expedition 2wd    4.6  1999    8    auto(l4)   r
# 76          ford          expedition 2wd    5.4  1999    8    auto(l4)   r
# 77          ford          expedition 2wd    5.4  2008    8    auto(l6)   r
# 78          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 79          ford            explorer 4wd    4.0  1999    6  manual(m5)   4
# 80          ford            explorer 4wd    4.0  1999    6    auto(l5)   4
# 81          ford            explorer 4wd    4.0  2008    6    auto(l5)   4
# 82          ford            explorer 4wd    4.6  2008    8    auto(l6)   4
# 83          ford            explorer 4wd    5.0  1999    8    auto(l4)   4
# 84          ford         f150 pickup 4wd    4.2  1999    6    auto(l4)   4
# 85          ford         f150 pickup 4wd    4.2  1999    6  manual(m5)   4
# ..           ...                     ...    ...   ...  ...         ...  ..
# 150       nissan                  maxima    3.5  2008    6    auto(av)   f
# 151       nissan          pathfinder 4wd    3.3  1999    6    auto(l4)   4
# 152       nissan          pathfinder 4wd    3.3  1999    6  manual(m5)   4
# 153       nissan          pathfinder 4wd    4.0  2008    6    auto(l5)   4
# 154       nissan          pathfinder 4wd    5.6  2008    8    auto(s5)   4
# 155      pontiac              grand prix    3.1  1999    6    auto(l4)   f
# 156      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 157      pontiac              grand prix    3.8  1999    6    auto(l4)   f
# 158      pontiac              grand prix    3.8  2008    6    auto(l4)   f
# 159      pontiac              grand prix    5.3  2008    8    auto(s4)   f
# 160       subaru            forester awd    2.5  1999    4  manual(m5)   4
# 161       subaru            forester awd    2.5  1999    4    auto(l4)   4
# 162       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 163       subaru            forester awd    2.5  2008    4  manual(m5)   4
# 164       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 165       subaru            forester awd    2.5  2008    4    auto(l4)   4
# 166       subaru             impreza awd    2.2  1999    4    auto(l4)   4
# 167       subaru             impreza awd    2.2  1999    4  manual(m5)   4
# 168       subaru             impreza awd    2.5  1999    4  manual(m5)   4
# 169       subaru             impreza awd    2.5  1999    4    auto(l4)   4
# 170       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 171       subaru             impreza awd    2.5  2008    4    auto(s4)   4
# 172       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 173       subaru             impreza awd    2.5  2008    4  manual(m5)   4
# 174       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4
# 175       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4
# 176       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4
# 177       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4
# 178       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4
# 179       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4
# 180       toyota                   camry    2.2  1999    4  manual(m5)   f
# 181       toyota                   camry    2.2  1999    4    auto(l4)   f
# 182       toyota                   camry    2.4  2008    4  manual(m5)   f
# 183       toyota                   camry    2.4  2008    4    auto(l5)   f
# 184       toyota                   camry    3.0  1999    6    auto(l4)   f
# 185       toyota                   camry    3.0  1999    6  manual(m5)   f
# 186       toyota                   camry    3.5  2008    6    auto(s6)   f
# 187       toyota            camry solara    2.2  1999    4    auto(l4)   f
# 188       toyota            camry solara    2.2  1999    4  manual(m5)   f
# 189       toyota            camry solara    2.4  2008    4  manual(m5)   f
# 190       toyota            camry solara    2.4  2008    4    auto(s5)   f
# 191       toyota            camry solara    3.0  1999    6    auto(l4)   f
# 192       toyota            camry solara    3.0  1999    6  manual(m5)   f
# 193       toyota            camry solara    3.3  2008    6    auto(s5)   f
# 194       toyota                 corolla    1.8  1999    4    auto(l3)   f
# 195       toyota                 corolla    1.8  1999    4    auto(l4)   f
# 196       toyota                 corolla    1.8  1999    4  manual(m5)   f
# 197       toyota                 corolla    1.8  2008    4  manual(m5)   f
# 198       toyota                 corolla    1.8  2008    4    auto(l4)   f
# 199       toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4
# 200       toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4
# 201       toyota       toyota tacoma 4wd    2.7  1999    4  manual(m5)   4
# 202       toyota       toyota tacoma 4wd    2.7  1999    4    auto(l4)   4
# 203       toyota       toyota tacoma 4wd    2.7  2008    4  manual(m5)   4
# 204       toyota       toyota tacoma 4wd    3.4  1999    6  manual(m5)   4
# 205       toyota       toyota tacoma 4wd    3.4  1999    6    auto(l4)   4
# 206       toyota       toyota tacoma 4wd    4.0  2008    6  manual(m6)   4
# 207       toyota       toyota tacoma 4wd    4.0  2008    6    auto(l5)   4
# 208   volkswagen                     gti    2.0  1999    4  manual(m5)   f
# 209   volkswagen                     gti    2.0  1999    4    auto(l4)   f
# 210   volkswagen                     gti    2.0  2008    4  manual(m6)   f
# 211   volkswagen                     gti    2.0  2008    4    auto(s6)   f
# 212   volkswagen                     gti    2.8  1999    6  manual(m5)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 214   volkswagen                   jetta    2.0  1999    4  manual(m5)   f
# 215   volkswagen                   jetta    2.0  1999    4    auto(l4)   f
# 216   volkswagen                   jetta    2.0  2008    4    auto(s6)   f
# 217   volkswagen                   jetta    2.0  2008    4  manual(m6)   f
# 218   volkswagen                   jetta    2.5  2008    5    auto(s6)   f
# 219   volkswagen                   jetta    2.5  2008    5  manual(m5)   f
# 220   volkswagen                   jetta    2.8  1999    6    auto(l4)   f
# 221   volkswagen                   jetta    2.8  1999    6  manual(m5)   f
# 222   volkswagen              new beetle    1.9  1999    4  manual(m5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 224   volkswagen              new beetle    2.0  1999    4  manual(m5)   f
# 225   volkswagen              new beetle    2.0  1999    4    auto(l4)   f
# 226   volkswagen              new beetle    2.5  2008    5  manual(m5)   f
# 227   volkswagen              new beetle    2.5  2008    5    auto(s6)   f
# 228   volkswagen                  passat    1.8  1999    4  manual(m5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 230   volkswagen                  passat    2.0  2008    4    auto(s6)   f
# 231   volkswagen                  passat    2.0  2008    4  manual(m6)   f
# 232   volkswagen                  passat    2.8  1999    6    auto(l5)   f
# 233   volkswagen                  passat    2.8  1999    6  manual(m5)   f
# 234   volkswagen                  passat    3.6  2008    6    auto(s6)   f
#
#      cty  hwy fl       class  mileage_difference  average_mileage
# 1     18   29  p     compact                  11             23.5
# 2     21   29  p     compact                   8             25.0
# 3     20   31  p     compact                  11             25.5
# 4     21   30  p     compact                   9             25.5
# 5     16   26  p     compact                  10             21.0
# 6     18   26  p     compact                   8             22.0
# 7     18   27  p     compact                   9             22.5
# 8     18   26  p     compact                   8             22.0
# 9     16   25  p     compact                   9             20.5
# 10    20   28  p     compact                   8             24.0
# 11    19   27  p     compact                   8             23.0
# 12    15   25  p     compact                  10             20.0
# 13    17   25  p     compact                   8             21.0
# 14    17   25  p     compact                   8             21.0
# 15    15   25  p     compact                  10             20.0
# 16    15   24  p     midsize                   9             19.5
# 17    17   25  p     midsize                   8             21.0
# 18    16   23  p     midsize                   7             19.5
# 19    14   20  r         suv                   6             17.0
# 20    11   15  e         suv                   4             13.0
# 21    14   20  r         suv                   6             17.0
# 22    13   17  r         suv                   4             15.0
# 23    12   17  r         suv                   5             14.5
# 24    16   26  p     2seater                  10             21.0
# 25    15   23  p     2seater                   8             19.0
# 26    16   26  p     2seater                  10             21.0
# 27    15   25  p     2seater                  10             20.0
# 28    15   24  p     2seater                   9             19.5
# 29    14   19  r         suv                   5             16.5
# 30    11   14  e         suv                   3             12.5
# 31    11   15  r         suv                   4             13.0
# 32    14   17  d         suv                   3             15.5
# 33    19   27  r     midsize                   8             23.0
# 34    22   30  r     midsize                   8             26.0
# 35    18   26  r     midsize                   8             22.0
# 36    18   29  r     midsize                  11             23.5
# 37    17   26  r     midsize                   9             21.5
# 38    18   24  r     minivan                   6             21.0
# 39    17   24  r     minivan                   7             20.5
# 40    16   22  r     minivan                   6             19.0
# 41    16   22  r     minivan                   6             19.0
# 42    17   24  r     minivan                   7             20.5
# 43    17   24  r     minivan                   7             20.5
# 44    11   17  e     minivan                   6             14.0
# 45    15   22  r     minivan                   7             18.5
# 46    15   21  r     minivan                   6             18.0
# 47    16   23  r     minivan                   7             19.5
# 48    16   23  r     minivan                   7             19.5
# 49    15   19  r      pickup                   4             17.0
# 50    14   18  r      pickup                   4             16.0
# 51    13   17  r      pickup                   4             15.0
# 52    14   17  r      pickup                   3             15.5
# 53    14   19  r      pickup                   5             16.5
# 54    14   19  r      pickup                   5             16.5
# 55     9   12  e      pickup                   3             10.5
# 56    11   17  r      pickup                   6             14.0
# 57    11   15  r      pickup                   4             13.0
# 58    13   17  r         suv                   4             15.0
# 59    13   17  r         suv                   4             15.0
# 60     9   12  e         suv                   3             10.5
# 61    13   17  r         suv                   4             15.0
# 62    11   16  r         suv                   5             13.5
# 63    13   18  r         suv                   5             15.5
# 64    11   15  r         suv                   4             13.0
# 65    12   16  r      pickup                   4             14.0
# 66     9   12  e      pickup                   3             10.5
# 67    13   17  r      pickup                   4             15.0
# 68    13   17  r      pickup                   4             15.0
# 69    12   16  r      pickup                   4             14.0
# 70     9   12  e      pickup                   3             10.5
# 71    11   15  r      pickup                   4             13.0
# 72    11   16  r      pickup                   5             13.5
# 73    13   17  r      pickup                   4             15.0
# 74    11   15  r      pickup                   4             13.0
# 75    11   17  r         suv                   6             14.0
# 76    11   17  r         suv                   6             14.0
# 77    12   18  r         suv                   6             15.0
# 78    14   17  r         suv                   3             15.5
# 79    15   19  r         suv                   4             17.0
# 80    14   17  r         suv                   3             15.5
# 81    13   19  r         suv                   6             16.0
# 82    13   19  r         suv                   6             16.0
# 83    13   17  r         suv                   4             15.0
# 84    14   17  r      pickup                   3             15.5
# 85    14   17  r      pickup                   3             15.5
# ..   ...  ... ..         ...                 ...              ...
# 150   19   25  p     midsize                   6             22.0
# 151   14   17  r         suv                   3             15.5
# 152   15   17  r         suv                   2             16.0
# 153   14   20  p         suv                   6             17.0
# 154   12   18  p         suv                   6             15.0
# 155   18   26  r     midsize                   8             22.0
# 156   16   26  p     midsize                  10             21.0
# 157   17   27  r     midsize                  10             22.0
# 158   18   28  r     midsize                  10             23.0
# 159   16   25  p     midsize                   9             20.5
# 160   18   25  r         suv                   7             21.5
# 161   18   24  r         suv                   6             21.0
# 162   20   27  r         suv                   7             23.5
# 163   19   25  p         suv                   6             22.0
# 164   20   26  r         suv                   6             23.0
# 165   18   23  p         suv                   5             20.5
# 166   21   26  r  subcompact                   5             23.5
# 167   19   26  r  subcompact                   7             22.5
# 168   19   26  r  subcompact                   7             22.5
# 169   19   26  r  subcompact                   7             22.5
# 170   20   25  p     compact                   5             22.5
# 171   20   27  r     compact                   7             23.5
# 172   19   25  p     compact                   6             22.0
# 173   20   27  r     compact                   7             23.5
# 174   15   20  r         suv                   5             17.5
# 175   16   20  r         suv                   4             18.0
# 176   15   19  r         suv                   4             17.0
# 177   15   17  r         suv                   2             16.0
# 178   16   20  r         suv                   4             18.0
# 179   14   17  r         suv                   3             15.5
# 180   21   29  r     midsize                   8             25.0
# 181   21   27  r     midsize                   6             24.0
# 182   21   31  r     midsize                  10             26.0
# 183   21   31  r     midsize                  10             26.0
# 184   18   26  r     midsize                   8             22.0
# 185   18   26  r     midsize                   8             22.0
# 186   19   28  r     midsize                   9             23.5
# 187   21   27  r     compact                   6             24.0
# 188   21   29  r     compact                   8             25.0
# 189   21   31  r     compact                  10             26.0
# 190   22   31  r     compact                   9             26.5
# 191   18   26  r     compact                   8             22.0
# 192   18   26  r     compact                   8             22.0
# 193   18   27  r     compact                   9             22.5
# 194   24   30  r     compact                   6             27.0
# 195   24   33  r     compact                   9             28.5
# 196   26   35  r     compact                   9             30.5
# 197   28   37  r     compact                   9             32.5
# 198   26   35  r     compact                   9             30.5
# 199   11   15  r         suv                   4             13.0
# 200   13   18  r         suv                   5             15.5
# 201   15   20  r      pickup                   5             17.5
# 202   16   20  r      pickup                   4             18.0
# 203   17   22  r      pickup                   5             19.5
# 204   15   17  r      pickup                   2             16.0
# 205   15   19  r      pickup                   4             17.0
# 206   15   18  r      pickup                   3             16.5
# 207   16   20  r      pickup                   4             18.0
# 208   21   29  r     compact                   8             25.0
# 209   19   26  r     compact                   7             22.5
# 210   21   29  p     compact                   8             25.0
# 211   22   29  p     compact                   7             25.5
# 212   17   24  r     compact                   7             20.5
# 213   33   44  d     compact                  11             38.5
# 214   21   29  r     compact                   8             25.0
# 215   19   26  r     compact                   7             22.5
# 216   22   29  p     compact                   7             25.5
# 217   21   29  p     compact                   8             25.0
# 218   21   29  r     compact                   8             25.0
# 219   21   29  r     compact                   8             25.0
# 220   16   23  r     compact                   7             19.5
# 221   17   24  r     compact                   7             20.5
# 222   35   44  d  subcompact                   9             39.5
# 223   29   41  d  subcompact                  12             35.0
# 224   21   29  r  subcompact                   8             25.0
# 225   19   26  r  subcompact                   7             22.5
# 226   20   28  r  subcompact                   8             24.0
# 227   20   29  r  subcompact                   9             24.5
# 228   21   29  p     midsize                   8             25.0
# 229   18   29  p     midsize                  11             23.5
# 230   19   28  p     midsize                   9             23.5
# 231   21   29  p     midsize                   8             25.0
# 232   16   26  p     midsize                  10             21.0
# 233   18   26  p     midsize                   8             22.0
# 234   17   26  p     midsize                   9             21.5
#
# [234 rows x 13 columns]

# %%
#K. Which dodge car has the best average mileage? The worst?
mpg[mpg.manufacturer == 'dodge'].sort_values(by='average_mileage', ascending=False).head(1)
mpg[mpg.manufacturer == 'dodge'].sort_values(by='average_mileage', ascending=False).tail(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  cty  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
#
#     hwy fl   class  mileage_difference  average_mileage
# 70   12  e  pickup                   3             10.5

# %%
#3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:
from pydataset import data
Mammals = data('Mammals')
#data('Mammals',show_doc=True)
Mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# 23    150.000   48.0    False     False
# 24    130.000   70.0    False     False
# 25    120.000   80.0    False     False
# 26    120.000   61.0    False     False
# 27    110.000   33.0    False     False
# 28    100.000   64.0    False     False
# 29     85.000   55.0    False     False
# 30     80.000   65.0    False     False
# 31     72.000   56.0    False     False
# 32     70.000   45.0    False     False
# 33     65.000   60.0    False     False
# 34     62.000   81.0    False     False
# 35     50.000  100.0    False     False
# 36     50.000   60.0    False     False
# 37     50.000   40.0    False     False
# 38     50.000   47.0    False     False
# 39     37.000  105.0    False     False
# 40     35.000   80.0    False     False
# 41     34.000   97.0    False     False
# 42     30.000   97.0    False     False
# 43     30.000   80.0    False     False
# 44     30.000   45.0    False     False
# 45     20.000   81.0    False     False
# 46    400.000   40.0    False     False
# 47    300.000   48.0    False     False
# 48    230.000   56.0    False     False
# 49    150.000   59.0    False     False
# 50    135.000   48.0    False     False
# 51     65.000   65.0    False     False
# 52     60.000   60.0    False     False
# 53     55.000  110.0    False     False
# 54     45.000   50.0    False     False
# 55     40.000   64.0    False     False
# 56     25.000   67.0    False     False
# 57     20.000   70.0    False     False
# 58     16.000   65.0    False     False
# 59     12.000   24.0    False      True
# 60     11.000   30.0    False      True
# 61     10.000   56.0    False     False
# 62      7.000   60.0    False     False
# 63      6.000   72.0    False     False
# 64      5.000   64.0    False     False
# 65      5.000   27.0    False      True
# 66      3.000   16.0    False      True
# 67    127.000   32.0    False     False
# 68     70.000   40.0    False      True
# 69     13.000   37.0    False      True
# 70      9.000    3.2    False      True
# 71      4.000   16.0    False     False
# 72      0.600   36.0    False     False
# 73      0.600   20.0    False     False
# 74      0.550   27.0    False     False
# 75      0.500   18.0    False     False
# 76      0.400   20.0    False     False
# 77      0.300   13.0    False     False
# 78      0.250    9.7    False     False
# 79      0.220   15.0    False     False
# 80      0.110    9.0    False     False
# 81      0.100   17.0    False     False
# 82      0.056   21.0     True     False
# 83      0.050   11.0    False     False
# 84      0.045   16.0    False     False
# 85      0.035   32.0     True     False
# 86      0.035   14.0     True     False
# 87      0.030    6.8    False     False
# 88      0.030    9.1    False     False
# 89      0.025   11.0    False     False
# 90      0.025    8.6    False     False
# 91      0.018    8.9    False     False
# 92      0.016   13.0    False     False
# 93      0.100    4.0    False     False
# 94      0.100    2.4    False     False
# 95      0.016    3.6    False     False
# 96      4.600   64.0     True     False
# 97      4.400   72.0     True     False
# 98      4.000   72.0     True     False
# 99      3.500   56.0     True     False
# 100     2.000   64.0     True     False
# 101     1.900   56.0     True     False
# 102     1.500   50.0     True     False
# 103     1.500   40.0     True     False
# 104    50.000   65.0    False     False
# 105     5.000    7.4    False      True
# 106     0.024   13.0    False     False
# 107     4.000    1.6    False      True

# %%
#A. How many rows and columns are there?
Mammals.shape
# Out:
# (107, 4)

# %%
#B. What are the data types?
Mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
#C. Summarize the dataframe with .info and .describe
Mammals.info(), Mammals.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
# weight      107 non-null float64
# speed       107 non-null float64
# hoppers     107 non-null bool
# specials    107 non-null bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB
# (None,             weight       speed
#  count   107.000000  107.000000
#  mean    278.688178   46.208411
#  std     839.608269   26.716778
#  min       0.016000    1.600000
#  25%       1.700000   22.500000
#  50%      34.000000   48.000000
#  75%     142.500000   65.000000
#  max    6000.000000  110.000000)

# %%
#D. What is the the weight of the fastest animal?
Mammals[['weight', 'speed']].sort_values(by='speed', ascending=False).head(5)
# Out:
#     weight  speed
# 53    55.0  110.0
# 39    37.0  105.0
# 35    50.0  100.0
# 41    34.0   97.0
# 42    30.0   97.0

# %%
#E. What is the overal percentage of specials?
sum(Mammals.specials==True)/len(Mammals)*100
(Mammals.specials==True).mean()*100
# Out:
# 9.345794392523365

# %%
##F. How many animals are hoppers that are above the median speed? What percentage is this?
num_animals = sum((Mammals.speed > Mammals.speed.median()) & (Mammals.hoppers == True))
num_animals # 7 hoopers 
total_hoppers = sum(Mammals.hoppers == True) # 11 total hoppers
(num_animals/total_hoppers)*100
# Out:
# 63.63636363636363
